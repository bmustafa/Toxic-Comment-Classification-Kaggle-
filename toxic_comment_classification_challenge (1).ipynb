# %% [markdown]
# # Conversation AI Toxic Comment Classification Challenge

# %% [markdown]
# Looking at comments pulled from Wikipedia, classify comments into any (or none) of the following categories:
# Toxic, Severe Toxic, Obscene, Threat, Insult, Identity Hate

# %%
import numpy as np 
import pandas as pd
import nltk
nltk.download('stopwords')
import re
from nltk import word_tokenize
from nltk.corpus import stopwords
from keras.preprocessing.sequence import pad_sequences
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from wordcloud import WordCloud
stopwords_set = set(stopwords.words('english'))
nltk.download('punkt')

import os


MAX_FEATURES = 20000
EMBEDDING_SIZE = 300
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')
sample_submission = pd.read_csv('sample_submission.csv')

# %%
#Let us take a took at the training data
train_df.iloc[:,1:]
# Out:
#                                              comment_text  ...  identity_hate
# 0       Explanation\nWhy the edits made under my usern...  ...              0
# 1       D'aww! He matches this background colour I'm s...  ...              0
# 2       Hey man, I'm really not trying to edit war. It...  ...              0
# 3       "\nMore\nI can't make any real suggestions on ...  ...              0
# 4       You, sir, are my hero. Any chance you remember...  ...              0
# ...                                                   ...  ...            ...
# 159566  ":::::And for the second time of asking, when ...  ...              0
# 159567  You should be ashamed of yourself \n\nThat is ...  ...              0
# 159568  Spitzer \n\nUmm, theres no actual article for ...  ...              0
# 159569  And it looks like it was actually you who put ...  ...              0
# 159570  "\nAnd ... I really don't think you understand...  ...              0
#
# [159571 rows x 7 columns]

# %%
# Look for null values
print(train_df.isnull().any())
print(test_df.isnull().any())
# Out:
# id               False
# comment_text     False
# toxic            False
# severe_toxic     False
# obscene          False
# threat           False
# insult           False
# identity_hate    False
# dtype: bool
# id              False
# comment_text    False
# dtype: bool

# %%
# Look at the frequency of occurence of tags in dataset
sns.heatmap(train_df.iloc[:,2:] == 1, cbar = False)

# %%
# Look at the frequency of tags within subset of dataset with toxic comments
sns.heatmap(train_df.iloc[np.unique(np.where(train_df.iloc[:,2:] == 1)[0]),2:] == 1, cbar = False)

# %%
# Check to see if several tags may co-occur
train_df['Tags'] = 0
for tag in train_df.columns.values[2:-1]:
    train_df['Tags'] += train_df[tag]
sns.distplot(train_df.loc[train_df['Tags'] != 0]['Tags'], hist = True, kde = False)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Investigate the relationship between Severely Toxic Comments and Toxic Comments
table = plt.table(confusion_matrix(train_df['toxic'], train_df['severe_toxic']), loc = 'center', colLabels = ['Not Severe', 'Severe'], rowLabels = ['Not Toxic', 'Toxic'])
ax = plt.gca()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.box(on = None)
table.scale(2,3)
plt.show()

# %%
# Look at correlation to get a better sense of the coocurrence of tags
sns.heatmap(train_df.iloc[:,2:-1].corr(), annot = True)

# %%
# Notice some key words will be lost and there are stylistic features of profanity
train_df.loc[(train_df['Tags'] != 0) & (train_df['comment_text'].str.contains('@'))]
# Out:
#                       id  ... Tags
# 12      0005c987bdfc9d4b  ...    1
# 238     0097dd5c29bf7a15  ...    4
# 437     011d0c0a6c8e5765  ...    3
# 638     01b9aa85cc61c03f  ...    3
# 2094    05a928e4d2101d4e  ...    4
# ...                  ...  ...  ...
# 151182  78dccc43b8d7a000  ...    3
# 154518  af0a6e1bec14c8bc  ...    1
# 154940  b676472355221ade  ...    2
# 157585  e08d6e1a6db20c1f  ...    2
# 158878  f5379a104a9276a2  ...    3
#
# [117 rows x 9 columns]

# %%
# Count the number of '!', '@' and '$' as perhaps a useful predictor (short coming of not using n-gram)
train_df['!'] = train_df["comment_text"].str.count('!')
train_df['@$'] = train_df["comment_text"].str.count('@') + train_df["comment_text"].str.count('$')
test_df['!'] = test_df["comment_text"].str.count('!')
test_df['@$'] = test_df["comment_text"].str.count('@') + test_df["comment_text"].str.count('$')
train_x_eng = np.column_stack([train_df['!'],train_df['@$']])
test_x_eng = np.column_stack([test_df['!'],test_df['@$']])
train_df
# Out:
#                       id  ... @$
# 0       0000997932d777bf  ...  1
# 1       000103f0d9cfb60f  ...  1
# 2       000113f07ec002fd  ...  1
# 3       0001b41b1c6bb37e  ...  1
# 4       0001d958c54c6e35  ...  1
# ...                  ...  ... ..
# 159566  ffe987279560d7ff  ...  1
# 159567  ffea4adeee384e90  ...  1
# 159568  ffee36eab5c267c9  ...  1
# 159569  fff125370e4aaaf3  ...  1
# 159570  fff46fc426af1f9a  ...  1
#
# [159571 rows x 11 columns]

# %%
# Check to see if there is any pattern in most common words from toxic comments that must be taken into consideration before parsing
all_text = ' '.join([word for word in ' '.join(train_df.loc[train_df['Tags'] != 0]['comment_text']).split() if word not in stopwords_set])
wordcloud = WordCloud().generate(all_text)
#plt.figure(figsize = (8, 8), facecolor = None) 
#plt.imshow(wordcloud) 
#plt.axis("off") 
#plt.tight_layout(pad = 0) 

#plt.show()

# %% [markdown]
# The above cell has been commented out due to profanity

# %%
def text_prepare(text):
    """Tokenization and Preprocessing."""
    
    # Make everything lowercase
    text = text.lower()
    
    # To deal with words not in Google Word2Vec Embeddings (probably not terrible significant)
    text = re.sub("doesnt", "does not", text)
    text = re.sub("doesn't", "does not", text)
    text = re.sub("dont", "do not", text)
    text = re.sub("don't", "do not", text)
    text = re.sub("isnt", "is not", text)
    text = re.sub("isn't", "is not", text)
    text = re.sub("wasnt", "was not", text)
    text = re.sub("wasn't", "was not", text)
    text = re.sub("didnt", "did not", text)
    text = re.sub("didn't", "did not", text)
    text = re.sub("behaviour", "behavior", text)
    text = re.sub("colour", "color", text)
    
    # Replace symbols,newline characters and remove stopwords. Then tokenize sentence 
    replace_by_space_re = re.compile('[/(){}\[\]\|@,;#\+_]')
    good_symbols_re = re.compile('[^0-9a-z ]')
    text = re.sub("\n", " ", text)
    text = replace_by_space_re.sub(' ', text)
    text = good_symbols_re.sub('', text)
    text = [x for x in nltk_tokenize(text) if x and x not in stopwords_set]
    
    return text


def nltk_tokenize(text):
    """Used to split a sentence into tokens"""
    
    tokens = word_tokenize(text)
    return tokens

# %%
# Clean comments in our training set and test set
train_x = train_df.iloc[:,1:2]
train_y = train_df.iloc[:,2:-3]
test_x = test_df.iloc[:,1:2]
train_cleaned_x = train_x['comment_text'].map(lambda x: text_prepare(x))
test_cleaned_x = test_x['comment_text'].map(lambda x: text_prepare(x))

# %%
train_cleaned_x
# Out:
# 0         [explanation, edits, made, username, hardcore,...
# 1         [daww, matches, background, color, im, seeming...
# 2         [hey, man, im, really, trying, edit, war, guy,...
# 3         [cant, make, real, suggestions, improvement, w...
# 4                [sir, hero, chance, remember, page, thats]
#                                 ...
# 159566    [second, time, asking, view, completely, contr...
# 159567    [ashamed, horrible, thing, put, talk, page, 12...
# 159568    [spitzer, umm, theres, actual, article, prosti...
# 159569    [looks, like, actually, put, speedy, first, ve...
# 159570    [really, think, understand, came, idea, bad, r...
# Name: comment_text, Length: 159571, dtype: object

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

# Use keras tokenizer to find 20,000 most important words and prepare for them to be fed into embedding layer
tokenizer = Tokenizer(MAX_FEATURES)
tokenizer.fit_on_texts(list(train_cleaned_x))
tokenizer.word_index
# Out:
# {'article': 1,
#  'page': 2,
#  'wikipedia': 3,
#  'talk': 4,
#  'please': 5,
#  'would': 6,
#  'one': 7,
#  'like': 8,
#  'see': 9,
#  'also': 10,
#  'think': 11,
#  'im': 12,
#  'know': 13,
#  'people': 14,
#  'edit': 15,
#  'articles': 16,
#  'use': 17,
#  'may': 18,
#  'time': 19,
#  'thanks': 20,
#  'even': 21,
#  'get': 22,
#  'make': 23,
#  'good': 24,
#  'information': 25,
#  'could': 26,
#  'well': 27,
#  'want': 28,
#  'deletion': 29,
#  'sources': 30,
#  'way': 31,
#  'name': 32,
#  'pages': 33,
#  'first': 34,
#  'new': 35,
#  'help': 36,
#  'editing': 37,
#  'source': 38,
#  'user': 39,
#  'go': 40,
#  'need': 41,
#  'say': 42,
#  'section': 43,
#  'edits': 44,
#  'thank': 45,
#  'made': 46,
#  'many': 47,
#  'much': 48,
#  'really': 49,
#  'used': 50,
#  'discussion': 51,
#  'find': 52,
#  'ive': 53,
#  'deleted': 54,
#  'fuck': 55,
#  'work': 56,
#  'since': 57,
#  'point': 58,
#  'right': 59,
#  'add': 60,
#  'look': 61,
#  'read': 62,
#  'image': 63,
#  'take': 64,
#  'still': 65,
#  'someone': 66,
#  'two': 67,
#  'back': 68,
#  'fact': 69,
#  'link': 70,
#  'said': 71,
#  'youre': 72,
#  'something': 73,
#  'going': 74,
#  'list': 75,
#  'blocked': 76,
#  'stop': 77,
#  'without': 78,
#  'content': 79,
#  'wiki': 80,
#  'hi': 81,
#  'editors': 82,
#  'thats': 83,
#  'block': 84,
#  'us': 85,
#  'history': 86,
#  'utc': 87,
#  'added': 88,
#  'http': 89,
#  'another': 90,
#  'removed': 91,
#  'might': 92,
#  'welcome': 93,
#  'note': 94,
#  'however': 95,
#  'sure': 96,
#  'place': 97,
#  'never': 98,
#  'case': 99,
#  'done': 100,
#  'put': 101,
#  'comment': 102,
#  'reason': 103,
#  'personal': 104,
#  'cant': 105,
#  'better': 106,
#  'seems': 107,
#  'using': 108,
#  'actually': 109,
#  'ask': 110,
#  'vandalism': 111,
#  'question': 112,
#  'feel': 113,
#  'anything': 114,
#  'believe': 115,
#  'links': 116,
#  'person': 117,
#  'things': 118,
#  'comments': 119,
#  'ill': 120,
#  'best': 121,
#  'policy': 122,
#  'part': 123,
#  '2': 124,
#  'hope': 125,
#  '1': 126,
#  'keep': 127,
#  'free': 128,
#  'already': 129,
#  'thing': 130,
#  'nothing': 131,
#  'change': 132,
#  'wrong': 133,
#  'though': 134,
#  'problem': 135,
#  'remove': 136,
#  'little': 137,
#  'subject': 138,
#  'others': 139,
#  'tag': 140,
#  'copyright': 141,
#  'trying': 142,
#  'must': 143,
#  'understand': 144,
#  'anyone': 145,
#  'speedy': 146,
#  'issue': 147,
#  'last': 148,
#  'give': 149,
#  'questions': 150,
#  'years': 151,
#  'agree': 152,
#  'rather': 153,
#  'editor': 154,
#  'let': 155,
#  'world': 156,
#  'different': 157,
#  'long': 158,
#  'reliable': 159,
#  'making': 160,
#  'come': 161,
#  'sorry': 162,
#  'reference': 163,
#  'got': 164,
#  'references': 165,
#  'mean': 166,
#  'try': 167,
#  'text': 168,
#  'continue': 169,
#  'found': 170,
#  'great': 171,
#  'leave': 172,
#  'fair': 173,
#  'english': 174,
#  'says': 175,
#  'original': 176,
#  'probably': 177,
#  'every': 178,
#  'simply': 179,
#  'word': 180,
#  '3': 181,
#  'users': 182,
#  'hello': 183,
#  'created': 184,
#  'either': 185,
#  'check': 186,
#  'state': 187,
#  'show': 188,
#  'ip': 189,
#  'site': 190,
#  'adding': 191,
#  'least': 192,
#  'delete': 193,
#  'consensus': 194,
#  'else': 195,
#  'enough': 196,
#  'request': 197,
#  'opinion': 198,
#  'far': 199,
#  'life': 200,
#  'day': 201,
#  'etc': 202,
#  'view': 203,
#  'around': 204,
#  'u': 205,
#  'id': 206,
#  'yes': 207,
#  'example': 208,
#  'reverted': 209,
#  'yet': 210,
#  'war': 211,
#  'contributions': 212,
#  'matter': 213,
#  'notable': 214,
#  'shit': 215,
#  'book': 216,
#  'given': 217,
#  'thought': 218,
#  'real': 219,
#  'admin': 220,
#  'material': 221,
#  'post': 222,
#  'account': 223,
#  'write': 224,
#  'images': 225,
#  'clearly': 226,
#  'encyclopedia': 227,
#  'support': 228,
#  'bad': 229,
#  'lot': 230,
#  'message': 231,
#  'needs': 232,
#  'evidence': 233,
#  'tell': 234,
#  'seem': 235,
#  'called': 236,
#  'maybe': 237,
#  'instead': 238,
#  'ever': 239,
#  'correct': 240,
#  'saying': 241,
#  'always': 242,
#  'clear': 243,
#  'states': 244,
#  'number': 245,
#  'important': 246,
#  'old': 247,
#  'true': 248,
#  'quite': 249,
#  'perhaps': 250,
#  'hate': 251,
#  'language': 252,
#  'whether': 253,
#  'media': 254,
#  'research': 255,
#  'consider': 256,
#  'written': 257,
#  'claim': 258,
#  'guidelines': 259,
#  'review': 260,
#  'term': 261,
#  'bit': 262,
#  'version': 263,
#  'criteria': 264,
#  'times': 265,
#  'nigger': 266,
#  'theres': 267,
#  'website': 268,
#  'getting': 269,
#  'fucking': 270,
#  'pov': 271,
#  'mention': 272,
#  'oh': 273,
#  'revert': 274,
#  'several': 275,
#  'makes': 276,
#  'considered': 277,
#  'hey': 278,
#  'changes': 279,
#  'words': 280,
#  'title': 281,
#  'idea': 282,
#  'address': 283,
#  'suck': 284,
#  'notice': 285,
#  'top': 286,
#  'current': 287,
#  'based': 288,
#  'following': 289,
#  'group': 290,
#  'listed': 291,
#  'means': 292,
#  'facts': 293,
#  'possible': 294,
#  'regarding': 295,
#  'care': 296,
#  'rules': 297,
#  'main': 298,
#  'second': 299,
#  'template': 300,
#  'general': 301,
#  'year': 302,
#  'attack': 303,
#  'mentioned': 304,
#  'left': 305,
#  'course': 306,
#  'whole': 307,
#  'kind': 308,
#  'statement': 309,
#  'date': 310,
#  'seen': 311,
#  'start': 312,
#  'include': 313,
#  'three': 314,
#  'issues': 315,
#  'wikipedias': 316,
#  'ass': 317,
#  'topic': 318,
#  'ok': 319,
#  'call': 320,
#  'end': 321,
#  'man': 322,
#  'less': 323,
#  'gay': 324,
#  'suggest': 325,
#  'including': 326,
#  'happy': 327,
#  'big': 328,
#  'sense': 329,
#  'create': 330,
#  'provide': 331,
#  'american': 332,
#  'days': 333,
#  '4': 334,
#  'redirect': 335,
#  'known': 336,
#  'move': 337,
#  'love': 338,
#  'notability': 339,
#  'appropriate': 340,
#  'sentence': 341,
#  'changed': 342,
#  '2005': 343,
#  'explain': 344,
#  'started': 345,
#  'contribs': 346,
#  'project': 347,
#  'info': 348,
#  'school': 349,
#  'included': 350,
#  'removing': 351,
#  'style': 352,
#  'mind': 353,
#  'anyway': 354,
#  'next': 355,
#  'picture': 356,
#  'although': 357,
#  'looking': 358,
#  'four': 359,
#  'relevant': 360,
#  'wont': 361,
#  'die': 362,
#  'sign': 363,
#  'answer': 364,
#  'away': 365,
#  'interest': 366,
#  'warning': 367,
#  'community': 368,
#  'per': 369,
#  'order': 370,
#  'youve': 371,
#  'recent': 372,
#  'summary': 373,
#  'news': 374,
#  'lol': 375,
#  'later': 376,
#  'discuss': 377,
#  'claims': 378,
#  'attacks': 379,
#  'policies': 380,
#  'currently': 381,
#  'public': 382,
#  'especially': 383,
#  'interested': 384,
#  'wrote': 385,
#  'neutral': 386,
#  'wish': 387,
#  'able': 388,
#  'specific': 389,
#  'full': 390,
#  'writing': 391,
#  'taken': 392,
#  '5': 393,
#  'names': 394,
#  'related': 395,
#  'position': 396,
#  'within': 397,
#  'line': 398,
#  'c': 399,
#  'wanted': 400,
#  'stuff': 401,
#  'appears': 402,
#  'official': 403,
#  'certainly': 404,
#  'faith': 405,
#  'nice': 406,
#  'everyone': 407,
#  'live': 408,
#  'report': 409,
#  'country': 410,
#  'according': 411,
#  'completely': 412,
#  'unless': 413,
#  'common': 414,
#  'pretty': 415,
#  'hes': 416,
#  'everything': 417,
#  'looks': 418,
#  'god': 419,
#  'single': 420,
#  'due': 421,
#  'process': 422,
#  '2006': 423,
#  'involved': 424,
#  'admins': 425,
#  'lead': 426,
#  'fat': 427,
#  'therefore': 428,
#  'web': 429,
#  'hard': 430,
#  'remember': 431,
#  'edited': 432,
#  'obviously': 433,
#  'came': 434,
#  'email': 435,
#  'response': 436,
#  'stay': 437,
#  'learn': 438,
#  'future': 439,
#  'truth': 440,
#  'behavior': 441,
#  'power': 442,
#  'past': 443,
#  'asked': 444,
#  'reading': 445,
#  'quote': 446,
#  'stupid': 447,
#  'false': 448,
#  'entry': 449,
#  'posted': 450,
#  'talking': 451,
#  'sandbox': 452,
#  'game': 453,
#  'ago': 454,
#  'placed': 455,
#  'similar': 456,
#  'city': 457,
#  'enwikipediaorg': 458,
#  'published': 459,
#  'whatever': 460,
#  'system': 461,
#  'today': 462,
#  'exactly': 463,
#  'paragraph': 464,
#  'political': 465,
#  'argument': 466,
#  'united': 467,
#  'faggot': 468,
#  'havent': 469,
#  'guy': 470,
#  'working': 471,
#  'took': 472,
#  'high': 473,
#  'useful': 474,
#  'moron': 475,
#  'noticed': 476,
#  'books': 477,
#  'regards': 478,
#  'reasons': 479,
#  'deleting': 480,
#  'guess': 481,
#  'appreciate': 482,
#  'particular': 483,
#  'form': 484,
#  'government': 485,
#  'british': 486,
#  'national': 487,
#  'dispute': 488,
#  '2007': 489,
#  'small': 490,
#  'reverting': 491,
#  'major': 492,
#  'lets': 493,
#  'five': 494,
#  'party': 495,
#  '10': 496,
#  'problems': 497,
#  'ones': 498,
#  '2008': 499,
#  'search': 500,
#  'often': 501,
#  'administrator': 502,
#  'provided': 503,
#  'become': 504,
#  'side': 505,
#  'tried': 506,
#  'reply': 507,
#  'rule': 508,
#  'needed': 509,
#  'almost': 510,
#  'along': 511,
#  'knowledge': 512,
#  'banned': 513,
#  'status': 514,
#  'stated': 515,
#  'username': 516,
#  'cheers': 517,
#  'law': 518,
#  'vandalize': 519,
#  'taking': 520,
#  'certain': 521,
#  'company': 522,
#  'fine': 523,
#  'points': 524,
#  'terms': 525,
#  'explanation': 526,
#  'film': 527,
#  'music': 528,
#  'shows': 529,
#  'otherwise': 530,
#  'whats': 531,
#  'uploaded': 532,
#  'sort': 533,
#  'generally': 534,
#  'entire': 535,
#  'description': 536,
#  'tags': 537,
#  'guys': 538,
#  'recently': 539,
#  'follow': 540,
#  'citation': 541,
#  'definition': 542,
#  'likely': 543,
#  '000': 544,
#  'aware': 545,
#  'saw': 546,
#  'present': 547,
#  'google': 548,
#  'cited': 549,
#  'alone': 550,
#  'soon': 551,
#  'ban': 552,
#  'indeed': 553,
#  'wp': 554,
#  'story': 555,
#  'decide': 556,
#  'views': 557,
#  'appear': 558,
#  'white': 559,
#  'open': 560,
#  'theory': 561,
#  'week': 562,
#  '6': 563,
#  'short': 564,
#  'family': 565,
#  'interesting': 566,
#  'actual': 567,
#  'contributing': 568,
#  'area': 569,
#  'external': 570,
#  'improve': 571,
#  'set': 572,
#  'piece': 573,
#  '2004': 574,
#  'contact': 575,
#  'band': 576,
#  'told': 577,
#  'internet': 578,
#  'test': 579,
#  'simple': 580,
#  'members': 581,
#  'moved': 582,
#  'various': 583,
#  'proposed': 584,
#  'arent': 585,
#  'allowed': 586,
#  'attention': 587,
#  'jew': 588,
#  'wouldnt': 589,
#  'obvious': 590,
#  '7': 591,
#  'unblock': 592,
#  'sites': 593,
#  'cite': 594,
#  'result': 595,
#  'disagree': 596,
#  'thus': 597,
#  'context': 598,
#  'type': 599,
#  'ie': 600,
#  'went': 601,
#  'cunt': 602,
#  'mr': 603,
#  'conflict': 604,
#  'university': 605,
#  'citations': 606,
#  'nonsense': 607,
#  'actions': 608,
#  'previous': 609,
#  'jews': 610,
#  'works': 611,
#  'category': 612,
#  'shouldnt': 613,
#  'bias': 614,
#  'hours': 615,
#  'author': 616,
#  'enjoy': 617,
#  'proper': 618,
#  'job': 619,
#  'file': 620,
#  'black': 621,
#  'longer': 622,
#  'john': 623,
#  'hell': 624,
#  'sourced': 625,
#  'together': 626,
#  'death': 627,
#  'sucks': 628,
#  'addition': 629,
#  'happened': 630,
#  'creating': 631,
#  'avoid': 632,
#  'valid': 633,
#  'npov': 634,
#  'automatically': 635,
#  'science': 636,
#  'deal': 637,
#  'worked': 638,
#  'series': 639,
#  'goes': 640,
#  'human': 641,
#  'seriously': 642,
#  'proof': 643,
#  'respect': 644,
#  'biased': 645,
#  'accepted': 646,
#  'bitch': 647,
#  'large': 648,
#  'helpful': 649,
#  'comes': 650,
#  'available': 651,
#  'exist': 652,
#  'opinions': 653,
#  'copy': 654,
#  'hand': 655,
#  'criticism': 656,
#  'tildes': 657,
#  'act': 658,
#  'rights': 659,
#  'sections': 660,
#  'living': 661,
#  'meaning': 662,
#  'necessary': 663,
#  'indicate': 664,
#  'months': 665,
#  'b': 666,
#  'action': 667,
#  'video': 668,
#  'accept': 669,
#  'german': 670,
#  'accurate': 671,
#  'personally': 672,
#  'statements': 673,
#  '2009': 674,
#  'attempt': 675,
#  'violation': 676,
#  'cause': 677,
#  'usually': 678,
#  'pig': 679,
#  'debate': 680,
#  'yeah': 681,
#  'july': 682,
#  'standard': 683,
#  'assume': 684,
#  'upon': 685,
#  'play': 686,
#  'theyre': 687,
#  'calling': 688,
#  'sex': 689,
#  'historical': 690,
#  'details': 691,
#  'rest': 692,
#  'youll': 693,
#  'multiple': 694,
#  'doubt': 695,
#  'tagged': 696,
#  '11': 697,
#  'serious': 698,
#  'dick': 699,
#  'blocking': 700,
#  'manual': 701,
#  'record': 702,
#  'afd': 703,
#  '24': 704,
#  'wikiproject': 705,
#  'separate': 706,
#  'fix': 707,
#  'online': 708,
#  'refer': 709,
#  'situation': 710,
#  'explaining': 711,
#  'heard': 712,
#  'level': 713,
#  'south': 714,
#  '8': 715,
#  'complete': 716,
#  'messages': 717,
#  'speak': 718,
#  '2010': 719,
#  'asking': 720,
#  'church': 721,
#  'lack': 722,
#  '20': 723,
#  'third': 724,
#  'data': 725,
#  'none': 726,
#  'prove': 727,
#  'subjects': 728,
#  'august': 729,
#  'apparently': 730,
#  'legal': 731,
#  'rationale': 732,
#  'period': 733,
#  'greek': 734,
#  'bullshit': 735,
#  'directly': 736,
#  'uk': 737,
#  'difference': 738,
#  'contribute': 739,
#  'team': 740,
#  'early': 741,
#  'wikipedian': 742,
#  'space': 743,
#  'huge': 744,
#  'march': 745,
#  'gets': 746,
#  'couple': 747,
#  'among': 748,
#  'supposed': 749,
#  '100': 750,
#  'quality': 751,
#  'countries': 752,
#  'military': 753,
#  'culture': 754,
#  'except': 755,
#  '9': 756,
#  'close': 757,
#  'india': 758,
#  'run': 759,
#  'meant': 760,
#  'changing': 761,
#  'significant': 762,
#  'uses': 763,
#  'jewish': 764,
#  'incorrect': 765,
#  'existing': 766,
#  'specifically': 767,
#  'pillars': 768,
#  'disruptive': 769,
#  'fish': 770,
#  'described': 771,
#  'produce': 772,
#  'head': 773,
#  'primary': 774,
#  'field': 775,
#  'error': 776,
#  'administrators': 777,
#  'friend': 778,
#  '12': 779,
#  'photo': 780,
#  'earlier': 781,
#  'release': 782,
#  'outside': 783,
#  'cases': 784,
#  'sometimes': 785,
#  'modern': 786,
#  'groups': 787,
#  'box': 788,
#  'purpose': 789,
#  'pictures': 790,
#  'table': 791,
#  'born': 792,
#  'inclusion': 793,
#  'vote': 794,
#  'particularly': 795,
#  'june': 796,
#  'character': 797,
#  'sock': 798,
#  'business': 799,
#  'readers': 800,
#  'gave': 801,
#  'anonymous': 802,
#  'abuse': 803,
#  'okay': 804,
#  'friends': 805,
#  'control': 806,
#  'arguments': 807,
#  'numbers': 808,
#  'shall': 809,
#  'penis': 810,
#  'january': 811,
#  'tutorial': 812,
#  'member': 813,
#  'linked': 814,
#  'home': 815,
#  'concerns': 816,
#  'red': 817,
#  'idiot': 818,
#  'thinking': 819,
#  'force': 820,
#  'reported': 821,
#  'happen': 822,
#  '2012': 823,
#  'song': 824,
#  'contest': 825,
#  'majority': 826,
#  'coming': 827,
#  'takes': 828,
#  'de': 829,
#  'wait': 830,
#  'creation': 831,
#  'allow': 832,
#  'eg': 833,
#  'bring': 834,
#  'giving': 835,
#  'worth': 836,
#  'kill': 837,
#  'decision': 838,
#  'totally': 839,
#  'house': 840,
#  'international': 841,
#  'scientific': 842,
#  'decided': 843,
#  'finally': 844,
#  'discussed': 845,
#  'lost': 846,
#  'putting': 847,
#  'absolutely': 848,
#  'mistake': 849,
#  'respond': 850,
#  'april': 851,
#  'towards': 852,
#  'entirely': 853,
#  'w': 854,
#  'independent': 855,
#  'merely': 856,
#  'dear': 857,
#  'press': 858,
#  'neither': 859,
#  'million': 860,
#  '15': 861,
#  'archive': 862,
#  'organization': 863,
#  'possibly': 864,
#  'balls': 865,
#  'unsigned': 866,
#  'wants': 867,
#  'standards': 868,
#  'irrelevant': 869,
#  'events': 870,
#  'population': 871,
#  'figure': 872,
#  'inappropriate': 873,
#  'album': 874,
#  'north': 875,
#  'advice': 876,
#  'looked': 877,
#  'chance': 878,
#  'posts': 879,
#  'posting': 880,
#  'civil': 881,
#  'religion': 882,
#  'removal': 883,
#  'asshole': 884,
#  'computer': 885,
#  'final': 886,
#  'examples': 887,
#  'unfortunately': 888,
#  'na': 889,
#  '2011': 890,
#  'named': 891,
#  'light': 892,
#  'court': 893,
#  'eat': 894,
#  'christian': 895,
#  'individual': 896,
#  'acceptable': 897,
#  'preceding': 898,
#  'meet': 899,
#  'understanding': 900,
#  'french': 901,
#  'p': 902,
#  'mine': 903,
#  'peoples': 904,
#  'requesting': 905,
#  'gives': 906,
#  'sound': 907,
#  'youd': 908,
#  'dead': 909,
#  'minor': 910,
#  'templates': 911,
#  'watch': 912,
#  'wanker': 913,
#  'across': 914,
#  'club': 915,
#  'license': 916,
#  'nobody': 917,
#  'highly': 918,
#  'fag': 919,
#  'face': 920,
#  'lists': 921,
#  'december': 922,
#  'experience': 923,
#  'games': 924,
#  'october': 925,
#  'poor': 926,
#  'barnstar': 927,
#  'bot': 928,
#  'former': 929,
#  'direct': 930,
#  'bark': 931,
#  'children': 932,
#  'persons': 933,
#  'verifiable': 934,
#  'despite': 935,
#  'sent': 936,
#  'knows': 937,
#  'gone': 938,
#  'reader': 939,
#  'behind': 940,
#  'half': 941,
#  'america': 942,
#  'weeks': 943,
#  'tv': 944,
#  '30': 945,
#  'event': 946,
#  'dog': 947,
#  'warring': 948,
#  'service': 949,
#  'september': 950,
#  'accounts': 951,
#  'century': 952,
#  'properly': 953,
#  'websites': 954,
#  'discussions': 955,
#  'special': 956,
#  'age': 957,
#  'cover': 958,
#  'missing': 959,
#  'mother': 960,
#  'nature': 961,
#  'religious': 962,
#  'map': 963,
#  'results': 964,
#  'november': 965,
#  'women': 966,
#  'money': 967,
#  'easily': 968,
#  'shown': 969,
#  'easy': 970,
#  'definitely': 971,
#  'sounds': 972,
#  'ahead': 973,
#  'noted': 974,
#  'fun': 975,
#  'basis': 976,
#  'expect': 977,
#  'body': 978,
#  'cool': 979,
#  'king': 980,
#  'study': 981,
#  'men': 982,
#  'spam': 983,
#  '25': 984,
#  'february': 985,
#  'featured': 986,
#  'local': 987,
#  'stand': 988,
#  'controversial': 989,
#  'strong': 990,
#  'solid': 991,
#  'israel': 992,
#  'cock': 993,
#  'movement': 994,
#  'nomination': 995,
#  'difficult': 996,
#  'aids': 997,
#  'introduction': 998,
#  'infobox': 999,
#  'reasonable': 1000,
#  ...}

# %%
# Convert words to sequence of integers
train_tokenized_x = tokenizer.texts_to_sequences(train_cleaned_x)
test_tokenized_x = tokenizer.texts_to_sequences(test_cleaned_x)
train_tokenized_x
# Out:
# [[526,
#   44,
#   46,
#   516,
#   4419,
#   11594,
#   1152,
#   209,
#   1945,
#   11034,
#   6401,
#   2521,
#   2704,
#   35,
#   1030,
#   15570,
#   2705,
#   5,
#   136,
#   300,
#   4,
#   2,
#   57,
#   12,
#   3256],
#  [2384, 1293, 1106, 12, 4164, 2464, 20, 4, 811, 697, 7265, 87],
#  [278,
#   322,
#   12,
#   49,
#   142,
#   15,
#   211,
#   470,
#   2034,
#   351,
#   360,
#   25,
#   451,
#   44,
#   238,
#   4,
#   2,
#   107,
#   296,
#   2166,
#   567,
#   348],
#  [105,
#   23,
#   219,
#   1245,
#   1888,
#   5573,
#   43,
#   2277,
#   376,
#   3388,
#   1122,
#   9076,
#   11,
#   165,
#   18,
#   41,
#   12801,
#   1271,
#   1077,
#   600,
#   310,
#   1077,
#   202,
#   376,
#   3365,
#   195,
#   34,
#   4221,
#   2166,
#   352,
#   165,
#   28,
#   5,
#   155,
#   13,
#   402,
#   5504,
#   16,
#   260,
#   481,
#   18,
#   1809,
#   2796,
#   2965,
#   291,
#   360,
#   484,
#   833,
#   1,
#   3048,
#   4525],
#  [1503, 3272, 878, 431, 2, 83],
#  [2400, 27, 17, 2049, 27, 4],
#  [1667, 3231, 204, 56],
#  [111, 3354, 1, 209, 5, 513],
#  [162,
#   180,
#   607,
#   1283,
#   354,
#   12,
#   8743,
#   224,
#   114,
#   1,
#   1307,
#   6,
#   2636,
#   111,
#   12,
#   856,
#   905,
#   1227,
#   7,
#   17,
#   349,
#   163,
#   4582,
#   7835,
#   2,
#   510,
#   1552,
#   524,
#   2456,
#   7835,
#   564,
#   7328,
#   1,
#   906,
#   348,
#   143,
#   66,
#   204,
#   3273,
#   13663],
#  [10503, 138, 1612],
#  [173,
#   17,
#   732,
#   20,
#   1181,
#   285,
#   63,
#   2,
#   2476,
#   63,
#   50,
#   173,
#   17,
#   526,
#   732,
#   17,
#   3,
#   16,
#   2173,
#   173,
#   17,
#   629,
#   7329,
#   173,
#   17,
#   300,
#   143,
#   10,
#   224,
#   63,
#   536,
#   2,
#   389,
#   526,
#   732,
#   108,
#   63,
#   1,
#   1707,
#   173,
#   17,
#   5,
#   40,
#   63,
#   536,
#   2,
#   15,
#   313,
#   173,
#   17,
#   732,
#   532,
#   173,
#   17,
#   254,
#   256,
#   1222,
#   1764,
#   173,
#   17,
#   732,
#   33,
#   52,
#   75,
#   63,
#   33,
#   432,
#   1337,
#   212,
#   70,
#   1537,
#   286,
#   3,
#   2,
#   1495,
#   2759,
#   63,
#   2999,
#   788,
#   94,
#   173,
#   17,
#   225,
#   532,
#   334,
#   18,
#   423,
#   2254,
#   526,
#   54,
#   7,
#   562,
#   532,
#   771,
#   264,
#   146,
#   29,
#   150,
#   5,
#   110,
#   254,
#   141,
#   150,
#   2,
#   45,
#   4,
#   346,
#   5943,
#   38,
#   20,
#   1181,
#   476,
#   1294,
#   536,
#   2,
#   381,
#   1841,
#   184,
#   79,
#   141,
#   514,
#   1955,
#   330,
#   620,
#   41,
#   1841,
#   2087,
#   141,
#   3143,
#   268,
#   70,
#   268,
#   392,
#   626,
#   6221,
#   954,
#   525,
#   17,
#   79,
#   678,
#   1556,
#   25,
#   95,
#   141,
#   1865,
#   157,
#   954,
#   2645,
#   141,
#   10,
#   2966,
#   27,
#   191,
#   38,
#   5,
#   60,
#   618,
#   141,
#   3067,
#   140,
#   620,
#   7,
#   129,
#   184,
#   472,
#   356,
#   2844,
#   668,
#   140,
#   50,
#   782,
#   1964,
#   115,
#   254,
#   1054,
#   264,
#   3266,
#   17,
#   17,
#   140,
#   7,
#   537,
#   291,
#   1946,
#   141,
#   537,
#   173,
#   17,
#   9,
#   1946,
#   141,
#   537,
#   390,
#   75,
#   141,
#   537,
#   17,
#   532,
#   1294,
#   256,
#   1222,
#   1764,
#   38,
#   696,
#   52,
#   75,
#   1294,
#   532,
#   289,
#   70,
#   1012,
#   4069,
#   225,
#   18,
#   54,
#   7,
#   562,
#   696,
#   771,
#   264,
#   146,
#   29,
#   63,
#   1351,
#   1178,
#   916,
#   369,
#   3266,
#   17,
#   63,
#   54,
#   2738,
#   615,
#   150,
#   5,
#   110,
#   254,
#   141,
#   150,
#   2,
#   45,
#   4,
#   346],
#  [322, 493, 377, 2618],
#  [278,
#   4,
#   4042,
#   290,
#   554,
#   24,
#   5034,
#   9282,
#   3478,
#   7,
#   5000,
#   150,
#   17069,
#   15571,
#   5107,
#   1900,
#   1045,
#   554,
#   110,
#   1435,
#   441,
#   147,
#   6118,
#   1015],
#  [312,
#   3682,
#   1118,
#   1015,
#   493,
#   260,
#   15,
#   1327,
#   3913,
#   379,
#   74,
#   12552,
#   466,
#   856,
#   23,
#   61,
#   8,
#   2125,
#   442,
#   220,
#   15,
#   177,
#   420,
#   3008,
#   946,
#   8976,
#   374,
#   1170,
#   3611,
#   214,
#   57,
#   661,
#   4463,
#   83,
#   404,
#   214,
#   8167,
#   2268,
#   274,
#   15,
#   4944,
#   14714,
#   587,
#   220,
#   1055,
#   61,
#   147,
#   2418,
#   1118,
#   204,
#   249,
#   14000,
#   250,
#   2927,
#   713,
#   1827,
#   3525,
#   51,
#   318,
#   1878,
#   213,
#   14715],
#  [273, 1822, 345, 807, 2464, 4000, 1175, 115, 466, 8, 71, 710, 3187, 5676, 20],
#  [957,
#   2157,
#   1255,
#   151,
#   247,
#   434,
#   985,
#   5899,
#   276,
#   1254,
#   1378,
#   160,
#   1775,
#   724,
#   1811,
#   1810,
#   7266,
#   16543,
#   1543,
#   723,
#   151,
#   247,
#   827,
#   3443,
#   1461,
#   207,
#   792,
#   5900,
#   49,
#   26,
#   2050,
#   8854,
#   5394,
#   26,
#   1453,
#   3744,
#   1952,
#   16544,
#   1164,
#   151,
#   247,
#   5900,
#   423,
#   627,
#   419,
#   8977,
#   819,
#   6661,
#   1164,
#   40,
#   77,
#   761,
#   302,
#   1591,
#   419],
#  [2024, 61, 161, 11, 16026, 68, 14363],
#  [335, 1977],
#  [58, 46, 329, 1116, 313, 4281, 2, 313, 25],
#  [166,
#   1301,
#   9,
#   72,
#   391,
#   73,
#   295,
#   351,
#   114,
#   450,
#   273,
#   27,
#   377,
#   21,
#   106,
#   206,
#   8,
#   110,
#   64,
#   2653,
#   61,
#   7267,
#   3091,
#   3565,
#   982,
#   291,
#   1367,
#   982,
#   1175,
#   626,
#   114,
#   11,
#   1339],
#  [295,
#   372,
#   44,
#   5,
#   62,
#   37,
#   527,
#   16,
#   44,
#   179,
#   24,
#   853,
#   47,
#   1828,
#   691,
#   229,
#   391,
#   5,
#   77,
#   2009,
#   3366],
#  [24, 13, 681, 12, 4443],
#  [242,
#   7268,
#   515,
#   242,
#   1726,
#   2261,
#   2020,
#   179,
#   248,
#   411,
#   8433,
#   153,
#   14716,
#   199,
#   414,
#   2807,
#   89,
#   7836,
#   5108,
#   10504,
#   66,
#   49,
#   41,
#   64,
#   61,
#   190,
#   22,
#   293,
#   65,
#   9,
#   2637,
#   245,
#   2,
#   2917,
#   12,
#   35,
#   28,
#   15,
#   114],
#  [3323, 704, 950, 823, 62, 3323, 390, 10181, 7195],
#  [2255,
#   464,
#   15,
#   144,
#   479,
#   372,
#   15,
#   1,
#   12,
#   96,
#   725,
#   1789,
#   133,
#   153,
#   12,
#   11793,
#   4017,
#   3982,
#   1141,
#   10505,
#   34,
#   464,
#   4545,
#   1311,
#   389,
#   138,
#   94,
#   16,
#   3434,
#   19010,
#   2848,
#   11035,
#   10,
#   115,
#   279,
#   1888,
#   228,
#   203,
#   15,
#   209,
#   6,
#   2706,
#   145,
#   8336,
#   16,
#   257,
#   289,
#   11210,
#   5356,
#   7837,
#   17070,
#   2015,
#   655,
#   16545,
#   623,
#   8744,
#   14717,
#   623,
#   8744,
#   1395,
#   112,
#   1986,
#   6,
#   287,
#   263,
#   3,
#   1,
#   7,
#   185,
#   4791,
#   1879,
#   1141,
#   4687,
#   6173,
#   464,
#   11,
#   250,
#   1625,
#   1526,
#   466,
#   15572,
#   9283,
#   518,
#   276,
#   1969,
#   4659,
#   518,
#   6760,
#   1024,
#   3401,
#   1864,
#   139,
#   2732,
#   4353,
#   3953,
#   3914,
#   6,
#   125,
#   12277,
#   15573,
#   4911,
#   58,
#   323,
#   8337,
#   21,
#   4660,
#   466,
#   7,
#   17633,
#   2274,
#   276,
#   1540,
#   3000,
#   1259,
#   518,
#   1630,
#   8338,
#   2849,
#   12,
#   3983,
#   15,
#   2035],
#  [10857, 16546, 275, 8080, 14718, 350, 21],
#  [267,
#   41,
#   1401,
#   3,
#   1,
#   46,
#   512,
#   138,
#   157,
#   30,
#   371,
#   100,
#   86,
#   1393,
#   8339,
#   1393,
#   481,
#   26,
#   4890,
#   2,
#   435,
#   26,
#   110,
#   66,
#   2928,
#   2],
#  [207,
#   960,
#   1291,
#   99,
#   1424,
#   3125,
#   3817,
#   3502,
#   6174,
#   685,
#   797,
#   17634,
#   16547,
#   234,
#   1031,
#   74,
#   169,
#   12021,
#   735,
#   6603,
#   1531,
#   3682,
#   18269,
#   1148,
#   1751,
#   343,
#   87],
#  [319, 64, 262, 56, 105, 249, 356, 208, 1984, 4792],
#  [927, 219, 200, 927, 493, 85, 3310],
#  [26, 222, 84, 4444, 1107, 130, 11, 12, 1985],
#  [96, 2081, 1167, 1314, 1504],
#  [4830, 877, 1, 563, 665, 454, 48, 1879],
#  [388,
#   222,
#   75,
#   1491,
#   129,
#   168,
#   620,
#   430,
#   1996,
#   53,
#   662,
#   22,
#   204,
#   3126,
#   907,
#   75,
#   19,
#   199,
#   10033,
#   366,
#   53,
#   1715,
#   359,
#   151,
#   142,
#   9170,
#   366,
#   2167,
#   2516,
#   390,
#   1765,
#   2929,
#   528,
#   888,
#   1565,
#   1232,
#   12,
#   65,
#   3381,
#   7,
#   2929,
#   528,
#   705,
#   384,
#   3,
#   4320,
#   2929,
#   528,
#   862,
#   393,
#   41,
#   4320,
#   528,
#   862,
#   181,
#   26,
#   17,
#   4320,
#   528,
#   862,
#   124,
#   528,
#   75,
#   49,
#   217,
#   142,
#   366,
#   139,
#   907,
#   75,
#   986,
#   16027,
#   68,
#   89,
#   528,
#   3,
#   128,
#   2929,
#   528,
#   12802,
#   164,
#   14001,
#   2568,
#   5181],
#  [27,
#   422,
#   118,
#   6495,
#   1263,
#   291,
#   2,
#   52,
#   61,
#   950,
#   574,
#   11,
#   1956,
#   3001,
#   399,
#   96,
#   1597,
#   9,
#   84,
#   305,
#   94,
#   399],
#  [160,
#   4128,
#   322,
#   466,
#   98,
#   1143,
#   396,
#   153,
#   7474,
#   3745,
#   775,
#   1680,
#   18270,
#   396,
#   463,
#   446,
#   175,
#   10,
#   73,
#   3382,
#   3221,
#   2560,
#   123,
#   258,
#   9171,
#   1288,
#   5277,
#   57,
#   47,
#   3745,
#   1108,
#   396,
#   6,
#   2334,
#   320,
#   2560,
#   4337,
#   123,
#   4338,
#   775,
#   1116,
#   4337,
#   321,
#   201,
#   1075,
#   3232,
#   16028,
#   1370,
#   781,
#   1545,
#   842,
#   2662,
#   1278,
#   23,
#   1075,
#   3232,
#   1,
#   515,
#   226,
#   3056,
#   842,
#   976],
#  [7393,
#   2233,
#   1267,
#   1860,
#   10858,
#   14364,
#   2057,
#   27,
#   2725,
#   389,
#   523,
#   170,
#   541,
#   3156,
#   4001,
#   981,
#   6119,
#   153,
#   2227,
#   199,
#   541,
#   754,
#   1111,
#   1663,
#   2725,
#   1254,
#   4754,
#   3808,
#   7072,
#   2233,
#   714,
#   1284,
#   343,
#   4001,
#   981,
#   6119,
#   2517,
#   7544,
#   2725,
#   288,
#   6927,
#   6927,
#   757,
#   7073,
#   535,
#   15137,
#   584,
#   7072,
#   2183,
#   1302,
#   542,
#   7072,
#   2233,
#   1267,
#   2139,
#   1284,
#   15574,
#   10701,
#   7072,
#   2233,
#   10,
#   1111,
#   15137,
#   14718,
#   2725,
#   1613,
#   1663,
#   13070,
#   464,
#   244,
#   1670,
#   17071,
#   13664,
#   10859,
#   10701,
#   2538,
#   17635,
#   2233,
#   250,
#   74,
#   68,
#   1302,
#   9172,
#   1300,
#   17636,
#   4001,
#   981,
#   288,
#   1483,
#   4609,
#   8434,
#   124,
#   2484,
#   5716,
#   5357,
#   2183,
#   4635,
#   326,
#   1726,
#   4635,
#   914,
#   1212],
#  [415,
#   48,
#   407,
#   5823,
#   1330,
#   3795,
#   3049,
#   792,
#   3144,
#   3827,
#   350,
#   95,
#   12,
#   96,
#   3726,
#   145,
#   3144,
#   1615,
#   7766,
#   5035,
#   115,
#   109,
#   1461,
#   3157,
#   898,
#   866,
#   102,
#   88,
#   729,
#   1378,
#   489,
#   87],
#  [81, 3774, 84, 10320, 3102, 11036, 554, 46, 275, 44, 771, 1967],
#  [339,
#   140,
#   455,
#   905,
#   1013,
#   54,
#   3,
#   100,
#   1,
#   107,
#   117,
#   290,
#   14,
#   576,
#   915,
#   522,
#   429,
#   79,
#   664,
#   138,
#   214,
#   1,
#   138,
#   350,
#   3,
#   264,
#   146,
#   29,
#   16,
#   1541,
#   339,
#   18,
#   54,
#   19,
#   5,
#   9,
#   259,
#   534,
#   646,
#   214,
#   664,
#   138,
#   1,
#   214,
#   18,
#   825,
#   1421,
#   60,
#   286,
#   2,
#   766,
#   1516,
#   140,
#   172,
#   94,
#   16,
#   4,
#   2,
#   711,
#   396,
#   5,
#   136,
#   146,
#   29,
#   140,
#   1190,
#   60,
#   25,
#   1,
#   6,
#   1226,
#   728,
#   339,
#   259,
#   259,
#   389,
#   1122,
#   16,
#   18,
#   28,
#   186,
#   264,
#   1159,
#   429,
#   593,
#   1257,
#   1213,
#   113,
#   128,
#   172,
#   94,
#   4,
#   2,
#   150],
#  [96,
#   426,
#   143,
#   3468,
#   4197,
#   86,
#   179,
#   88,
#   170,
#   663,
#   145,
#   1354,
#   341,
#   2654,
#   426,
#   93,
#   136,
#   23,
#   44,
#   4],
#  [6994,
#   11,
#   11,
#   1889,
#   78,
#   1022,
#   139,
#   2677,
#   88,
#   73,
#   436,
#   13,
#   546,
#   903,
#   399,
#   6268,
#   7545],
#  [324,
#   559,
#   5983,
#   10860,
#   5150,
#   67,
#   1063,
#   3848,
#   102,
#   7330,
#   2256,
#   16029,
#   610,
#   6715,
#   7629,
#   145,
#   126,
#   17637,
#   773,
#   6761,
#   40,
#   7074,
#   124,
#   695,
#   280,
#   1847,
#   3727,
#   9077,
#   5278,
#   23,
#   15575,
#   40,
#   6716,
#   324,
#   14365,
#   181,
#   34,
#   148,
#   367,
#   270,
#   324,
#   361,
#   482,
#   1136,
#   6,
#   224,
#   2,
#   387,
#   4,
#   1103,
#   8340,
#   2011,
#   505],
#  [55, 6604, 960, 317, 5603],
#  [12,
#   162,
#   12,
#   162,
#   6717,
#   204,
#   2533,
#   4,
#   2,
#   229,
#   13,
#   911,
#   4,
#   2,
#   1625,
#   1541,
#   10702,
#   13,
#   5984,
#   10703,
#   777,
#   12,
#   74,
#   40,
#   686,
#   3599],
#  [115,
#   656,
#   547,
#   9284,
#   508,
#   386,
#   58,
#   203,
#   1776,
#   1308,
#   21,
#   1069,
#   260,
#   964,
#   19788,
#   819,
#   1047,
#   14002,
#   65,
#   1365,
#   633,
#   13,
#   1112,
#   440,
#   1116,
#   2441,
#   16548,
#   10,
#   123,
#   255,
#   7932,
#   555,
#   294,
#   1517,
#   448,
#   263,
#   870,
#   10704,
#   1319,
#   71,
#   630,
#   1848,
#   2613,
#   3660,
#   4688,
#   2613,
#   3660,
#   152,
#   15,
#   386,
#   294,
#   134,
#   1401,
#   65,
#   73,
#   143,
#   100],
#  [58, 340, 1227, 339, 1631],
#  [280, 72, 3127, 109, 58, 114, 132, 1311, 140, 640],
#  [378,
#   2150,
#   2684,
#   3274,
#   3134,
#   710,
#   2446,
#   24,
#   405,
#   24,
#   2816,
#   123,
#   98,
#   1056,
#   311,
#   103,
#   325,
#   92,
#   12278,
#   5747,
#   116,
#   7,
#   389,
#   7196,
#   429,
#   2,
#   213,
#   239,
#   46,
#   1025,
#   2504,
#   213,
#   21,
#   304,
#   1228,
#   226,
#   495,
#   3163,
#   6,
#   1802,
#   6,
#   604,
#   366,
#   6,
#   110,
#   597,
#   4420,
#   24,
#   405,
#   2248,
#   153,
#   160,
#   5036,
#   4145,
#   1118,
#   19011],
#  [478,
#   14003,
#   194,
#   5182,
#   378,
#   935,
#   724,
#   31,
#   5183,
#   4507,
#   442,
#   153,
#   3600,
#   4891,
#   820,
#   199,
#   12,
#   545,
#   10861,
#   1292,
#   477,
#   138,
#   194,
#   194,
#   2132,
#   2613,
#   1738,
#   4507,
#   224,
#   1132,
#   614,
#   366,
#   290,
#   4636,
#   7767,
#   13071,
#   4636,
#   4507,
#   724,
#   31,
#   165,
#   188,
#   15576,
#   12,
#   545,
#   235,
#   11,
#   4507,
#   6995,
#   4198,
#   856,
#   3746,
#   59,
#   461,
#   1592,
#   713,
#   7132,
#   28,
#   101,
#   48,
#   3311,
#   4199,
#   294,
#   306,
#   161,
#   4200,
#   14,
#   396,
#   224,
#   477,
#   208,
#   21,
#   9897,
#   1318,
#   4507,
#   929,
#   813,
#   2103,
#   495,
#   2584,
#   495,
#   2967,
#   829,
#   167,
#   958,
#   2538,
#   724,
#   31,
#   514,
#   322,
#   385,
#   5216,
#   1908,
#   2968,
#   573,
#   14719],
#  [8168,
#   71,
#   400,
#   4,
#   1072,
#   426,
#   43,
#   257,
#   16549,
#   9767,
#   3894,
#   12803,
#   1086,
#   26,
#   2871,
#   8169,
#   17072,
#   218,
#   108,
#   743,
#   11393,
#   12803,
#   8169,
#   9078,
#   13072,
#   2942,
#   629,
#   9078,
#   12803,
#   69,
#   3669,
#   10034,
#   108,
#   4912,
#   651,
#   2104,
#   295,
#   629,
#   9078,
#   12803,
#   69,
#   3669,
#   10034,
#   108,
#   4912,
#   651,
#   2104,
#   309,
#   402,
#   161,
#   1685,
#   181,
#   2,
#   496,
#   390,
#   446,
#   1386,
#   13072,
#   550,
#   345,
#   10035,
#   2580,
#   265,
#   1386,
#   14366,
#   3367,
#   483,
#   6175,
#   277,
#   10034,
#   108,
#   4912,
#   651,
#   2104,
#   357,
#   2585,
#   92,
#   504,
#   10034,
#   1229,
#   439,
#   106,
#   2104,
#   504,
#   651,
#   1383,
#   13665,
#   1383,
#   7546,
#   9768,
#   640,
#   42,
#   809,
#   9,
#   4912,
#   651,
#   1792,
#   2104,
#   5313,
#   23,
#   509,
#   774,
#   231,
#   28,
#   172,
#   939,
#   41,
#   4070,
#   2104,
#   8,
#   23,
#   743,
#   13072,
#   7197,
#   461,
#   766,
#   2104,
#   6,
#   558,
#   7630,
#   163,
#   13072,
#   1386,
#   2580,
#   265,
#   1386,
#   14366,
#   1386,
#   3411,
#   2548,
#   135,
#   1803,
#   13072,
#   1386,
#   323,
#   2580,
#   265,
#   14366,
#   1386,
#   2096,
#   4912,
#   651,
#   1792,
#   2104,
#   16030,
#   1511,
#   409,
#   244,
#   2978,
#   1511,
#   4093,
#   981,
#   1039,
#   1086,
#   2269,
#   10034,
#   12022,
#   245,
#   3389,
#   461,
#   832,
#   3135,
#   7394,
#   3526,
#   11037,
#   743,
#   13072,
#   7394,
#   331,
#   1716,
#   1247,
#   3412,
#   1124,
#   1124,
#   6662,
#   7,
#   3849,
#   1086,
#   2132,
#   1699,
#   1532,
#   108,
#   766,
#   7394,
#   977,
#   245,
#   3849,
#   2942,
#   727,
#   2848,
#   2269,
#   10034,
#   8341,
#   1639,
#   1699,
#   1393,
#   1803,
#   412,
#   1662,
#   10862,
#   6928,
#   2871,
#   743,
#   1001,
#   295,
#   12803,
#   8169,
#   9078,
#   13072,
#   2942,
#   1970,
#   7838,
#   409,
#   7839,
#   7701,
#   4559,
#   301,
#   13072,
#   1086,
#   61,
#   8169,
#   11037,
#   13072,
#   2942,
#   390,
#   446,
#   3566,
#   584,
#   12803,
#   1532,
#   13666,
#   10036,
#   9631,
#   11794,
#   10036,
#   743,
#   57,
#   11794,
#   2249,
#   743,
#   13072,
#   4263],
#  [22, 4105, 22, 164, 2606, 105, 101, 22, 55, 22, 4105, 12, 4105, 59],
#  [2375, 6070, 1624, 13, 410, 249, 414, 3177, 31, 51, 1990, 10037, 28, 1593],
#  [20,
#   9173,
#   206,
#   6446,
#   12,
#   4852,
#   514,
#   2540,
#   485,
#   326,
#   987,
#   485,
#   141,
#   514,
#   3022,
#   74,
#   730,
#   611,
#   3527,
#   485,
#   678,
#   382,
#   1566,
#   456,
#   1,
#   2540,
#   481,
#   120,
#   255,
#   17638,
#   109,
#   159,
#   31,
#   110,
#   141,
#   36,
#   1829,
#   8,
#   1056,
#   3136,
#   12,
#   108,
#   173,
#   17,
#   732,
#   57,
#   633,
#   63,
#   50,
#   1,
#   20],
#  [3092, 120, 179, 4421, 285, 20],
#  [447, 1616, 215, 77, 480, 401, 884, 40, 362, 1686, 3300, 40, 624],
#  [2669, 8342, 433, 2234, 5217, 317],
#  [1087,
#   260,
#   1395,
#   12,
#   162,
#   42,
#   1404,
#   16,
#   7395,
#   275,
#   492,
#   497,
#   1111,
#   16,
#   609,
#   1087,
#   2447,
#   3068,
#   71,
#   16,
#   7768,
#   622,
#   86,
#   254,
#   587,
#   4054,
#   1755,
#   485,
#   5677,
#   2262,
#   1179,
#   25,
#   43,
#   13343,
#   10,
#   1179,
#   25,
#   6176,
#   692,
#   1,
#   5,
#   61,
#   19789,
#   707,
#   135,
#   19790,
#   95,
#   1,
#   9394,
#   899,
#   9394,
#   264,
#   478],
#  [576,
#   33,
#   29,
#   218,
#   938,
#   480,
#   102,
#   450,
#   4,
#   2,
#   193,
#   2323,
#   8435,
#   838,
#   193,
#   2,
#   1503,
#   65,
#   2726,
#   4181,
#   55,
#   2581,
#   68,
#   299,
#   11,
#   200,
#   504,
#   100,
#   64,
#   158,
#   4755,
#   404,
#   545,
#   200,
#   3434,
#   1306,
#   885,
#   14367,
#   2541,
#   6605,
#   1565,
#   22,
#   2291,
#   10863,
#   121,
#   2034,
#   5944,
#   699,
#   2304,
#   28,
#   104,
#   303,
#   2884,
#   27,
#   229,
#   371,
#   164,
#   7,
#   40,
#   973,
#   193,
#   2335,
#   3,
#   120,
#   23,
#   90,
#   7,
#   161,
#   59,
#   68,
#   4,
#   2,
#   1766,
#   699,
#   26,
#   6663,
#   2528,
#   302,
#   247,
#   1007,
#   18271,
#   142,
#   23,
#   32,
#   576,
#   23,
#   327,
#   270,
#   14,
#   72,
#   12804,
#   420,
#   247,
#   322,
#   619,
#   3145,
#   250,
#   66,
#   195,
#   74,
#   540,
#   6663,
#   142,
#   1108,
#   68,
#   1076,
#   195,
#   26,
#   4401,
#   8,
#   207,
#   23,
#   3488,
#   1338,
#   361,
#   241,
#   114,
#   511,
#   1436,
#   120,
#   2329,
#   120,
#   894,
#   932,
#   397,
#   6606,
#   42,
#   884,
#   960,
#   270,
#   993,
#   8978,
#   40,
#   894,
#   2036,
#   17639,
#   7267,
#   6761,
#   5857,
#   55,
#   73,
#   406,
#   237,
#   40,
#   9285,
#   747,
#   15577,
#   9174,
#   987,
#   7396,
#   3632,
#   1991,
#   137,
#   622,
#   314,
#   1328,
#   3120,
#   2229,
#   884,
#   83,
#   106,
#   178,
#   31],
#  [105,
#   115,
#   427,
#   9,
#   372,
#   16550,
#   3120,
#   188,
#   4222,
#   15138,
#   418,
#   848,
#   4071,
#   101,
#   967,
#   206,
#   42,
#   105,
#   2270,
#   2395,
#   489,
#   909,
#   5470,
#   2126,
#   127,
#   4223,
#   6033,
#   102,
#   6177,
#   136,
#   4661],
#  [10321, 2, 6, 10, 1734, 253, 8, 5638, 1043],
#  [10182,
#   8,
#   3023,
#   9395,
#   1647,
#   1288,
#   1933,
#   48,
#   8,
#   861,
#   302,
#   247,
#   1066,
#   7769,
#   1822,
#   7475,
#   98,
#   689,
#   65,
#   1492,
#   117,
#   109,
#   7475,
#   7769,
#   689,
#   27,
#   1922,
#   689,
#   10182],
#  [335, 8660, 8745],
#  [895,
#   2943,
#   81,
#   26,
#   5,
#   77,
#   6356,
#   612,
#   895,
#   2943,
#   1900,
#   2601,
#   1901,
#   661,
#   1067,
#   1157,
#   133,
#   1901,
#   134,
#   2943,
#   938,
#   232,
#   77,
#   2943,
#   2542,
#   613,
#   2073,
#   236,
#   895,
#   2943,
#   895,
#   1205,
#   792,
#   1067,
#   1157,
#   236,
#   895,
#   1909,
#   103,
#   550,
#   5,
#   144,
#   7770,
#   1901,
#   600,
#   4723,
#   3375,
#   718,
#   10038,
#   134,
#   230,
#   7840,
#   66,
#   3010,
#   10038,
#   644,
#   69,
#   13344,
#   1781,
#   28,
#   320,
#   407,
#   2943,
#   687,
#   1067,
#   1157,
#   2162,
#   395,
#   2943,
#   2542,
#   5,
#   77,
#   5471,
#   685,
#   85,
#   4422,
#   1909,
#   2542,
#   83,
#   8979,
#   4,
#   1600,
#   1751,
#   489,
#   87],
#  [1606, 4423, 2151, 175, 32, 1037, 13, 129, 1037, 32, 4423, 175, 10039, 175],
#  [44,
#   24,
#   2872,
#   8,
#   274,
#   24,
#   44,
#   72,
#   447,
#   144,
#   224,
#   27,
#   274,
#   44,
#   371,
#   843,
#   2426,
#   8252,
#   7771,
#   135,
#   237,
#   7,
#   201,
#   693,
#   2918,
#   2009,
#   5184,
#   347],
#  [4560, 585, 5151, 15, 11394, 22, 209, 4],
#  [601, 204, 19, 404, 99, 19, 376, 2108, 520, 932, 1398, 957],
#  [143,
#   4146,
#   16551,
#   6447,
#   319,
#   7547,
#   538,
#   391,
#   49,
#   276,
#   113,
#   162,
#   239,
#   40,
#   518,
#   349,
#   6,
#   731,
#   5279,
#   229],
#  [142, 5574, 42, 119, 2118, 142, 325, 176, 255, 3, 59],
#  [1340, 1, 1729, 953, 163, 259, 147, 2019, 315, 582, 5185],
#  [6,
#   482,
#   2016,
#   9,
#   2339,
#   5,
#   1451,
#   19,
#   622,
#   1565,
#   142,
#   1681,
#   185,
#   10183,
#   1850,
#   19012,
#   2248,
#   1301,
#   622,
#   147,
#   809,
#   172,
#   550,
#   2001,
#   139,
#   1587,
#   11395,
#   587],
#  [176, 255, 1370, 1823],
#  [3758,
#   1423,
#   166,
#   7,
#   130,
#   20,
#   898,
#   866,
#   102,
#   88,
#   306,
#   180,
#   1423,
#   2746,
#   5314,
#   1423,
#   128,
#   187,
#   4,
#   446,
#   28,
#   3612,
#   598,
#   261,
#   50,
#   253,
#   3383,
#   94,
#   71,
#   4165,
#   2542,
#   98,
#   304,
#   2204,
#   219,
#   1626,
#   662,
#   2204,
#   662,
#   261,
#   8170,
#   50,
#   484,
#   3,
#   2204,
#   525,
#   1275,
#   1168,
#   1440,
#   129,
#   13,
#   12,
#   96,
#   4,
#   2204,
#   525,
#   1275,
#   1168,
#   1440,
#   410,
#   2204,
#   525,
#   1275,
#   1440,
#   898,
#   866,
#   102,
#   88,
#   273,
#   1307,
#   1440,
#   1440,
#   187,
#   1162,
#   403,
#   536,
#   1168,
#   1440,
#   531,
#   58,
#   9632,
#   1838,
#   4,
#   1440,
#   1162,
#   403,
#   32,
#   1440,
#   898,
#   866,
#   102,
#   88,
#   89,
#   1390,
#   445,
#   10,
#   9,
#   89,
#   1390,
#   718,
#   898,
#   866,
#   102,
#   88],
#  [3711, 175, 19, 3728, 32, 19, 2856, 968, 61, 655, 242, 3728, 32, 61, 27],
#  [64, 7772, 1392, 1170],
#  [83,
#   12,
#   358,
#   418,
#   8,
#   204,
#   699,
#   4,
#   33,
#   134,
#   131,
#   229,
#   134,
#   418,
#   8,
#   6607,
#   1910,
#   953,
#   45,
#   1165,
#   10,
#   517],
#  [2168,
#   49,
#   663,
#   32,
#   85,
#   244,
#   2205,
#   149,
#   245,
#   244,
#   332,
#   227,
#   3368,
#   7,
#   9,
#   178,
#   420,
#   85,
#   244,
#   2205,
#   891,
#   10184],
#  [723,
#   922,
#   423,
#   87,
#   143,
#   686,
#   1309,
#   6357,
#   991,
#   124,
#   501,
#   7397,
#   9513,
#   6357,
#   7631,
#   601,
#   991,
#   8661,
#   532,
#   5604,
#   12279],
#  [81, 68, 148, 367, 77, 3188, 44, 362],
#  [584,
#   29,
#   300,
#   88,
#   1,
#   1657,
#   54,
#   411,
#   584,
#   29,
#   422,
#   212,
#   1095,
#   1,
#   18,
#   2419,
#   316,
#   264,
#   793,
#   29,
#   285,
#   344,
#   9,
#   10,
#   3,
#   316,
#   29,
#   122,
#   18,
#   1176,
#   584,
#   29,
#   351,
#   285,
#   5,
#   344,
#   596,
#   584,
#   29,
#   15,
#   373,
#   4,
#   2,
#   10,
#   5,
#   256,
#   1374,
#   1,
#   283,
#   315,
#   1414,
#   21,
#   134,
#   351,
#   29,
#   285,
#   1176,
#   29,
#   584,
#   29,
#   422,
#   1,
#   18,
#   65,
#   54,
#   2384,
#   146,
#   29,
#   264,
#   936,
#   16,
#   29,
#   18,
#   54,
#   194,
#   193,
#   1402,
#   152,
#   29,
#   1,
#   117,
#   46,
#   2109,
#   44,
#   2,
#   5,
#   60,
#   286],
#  [842,
#   5218,
#   946,
#   677,
#   666,
#   677,
#   666,
#   4002,
#   2152,
#   533,
#   2385,
#   1930,
#   364,
#   150,
#   1073,
#   27,
#   135,
#   3945,
#   1073,
#   208,
#   412,
#   13667,
#   275,
#   492,
#   2978,
#   497,
#   34,
#   412,
#   1404,
#   272,
#   69,
#   1869,
#   940,
#   206,
#   249,
#   2376,
#   1124,
#   1730,
#   636,
#   92,
#   61,
#   9,
#   2096,
#   14720,
#   52,
#   1777,
#   358,
#   46,
#   1777,
#   358,
#   14720,
#   4018,
#   157,
#   241,
#   46,
#   73,
#   1124,
#   206,
#   2465,
#   3221,
#   73,
#   783,
#   461,
#   5985,
#   677,
#   636,
#   329,
#   180,
#   4339,
#   1573,
#   3091,
#   1508,
#   10506,
#   1454,
#   19791,
#   5219,
#   48,
#   8436,
#   184,
#   171,
#   9175,
#   233,
#   1573,
#   19791,
#   1129,
#   166,
#   49,
#   299,
#   1730,
#   636,
#   828,
#   1311,
#   512,
#   131,
#   336,
#   842,
#   518,
#   413,
#   16552,
#   1476,
#   143,
#   2477,
#   1577,
#   8746,
#   725,
#   68,
#   206,
#   2965,
#   773,
#   321,
#   759,
#   204,
#   512,
#   3301,
#   924,
#   7,
#   42,
#   10322,
#   26,
#   2739,
#   3552,
#   624,
#   206,
#   6120,
#   161,
#   533,
#   12805,
#   671,
#   4129,
#   3552,
#   7702,
#   10322,
#   144,
#   105,
#   2277,
#   206,
#   11211,
#   59,
#   19013,
#   828,
#   114,
#   716,
#   1639,
#   1730,
#   526,
#   2277,
#   42,
#   27,
#   13668,
#   822,
#   66,
#   143,
#   2152,
#   18272,
#   636,
#   11795,
#   73,
#   144,
#   206,
#   160,
#   808,
#   844,
#   208,
#   6496,
#   666,
#   4002,
#   1699,
#   83,
#   27,
#   24,
#   13667,
#   208,
#   755,
#   644,
#   200,
#   1124,
#   666,
#   2230,
#   6496,
#   208,
#   92,
#   2457,
#   9079,
#   636,
#   909,
#   978,
#   666,
#   5056,
#   1960,
#   9,
#   1455,
#   909,
#   3880,
#   8747,
#   1960,
#   355,
#   19,
#   9,
#   978,
#   5056,
#   1960,
#   177,
#   872,
#   83,
#   1233,
#   200,
#   1124,
#   7,
#   6175,
#   784,
#   5985,
#   579,
#   329,
#   6496,
#   842,
#   371,
#   98,
#   109,
#   3601,
#   666,
#   1008,
#   666,
#   3698,
#   2385,
#   6829,
#   98,
#   3601,
#   329,
#   636],
#  [278,
#   476,
#   119,
#   8253,
#   51,
#   2,
#   843,
#   57,
#   917,
#   755,
#   66,
#   223,
#   5152,
#   71,
#   6,
#   6121,
#   132,
#   2,
#   137,
#   23,
#   173,
#   400,
#   234,
#   218,
#   6,
#   8,
#   13,
#   342,
#   280,
#   286,
#   34,
#   464,
#   88,
#   73,
#   299,
#   7,
#   2569,
#   83,
#   523,
#   218,
#   57,
#   1708,
#   131,
#   21,
#   71,
#   92,
#   8748,
#   234],
#  [851,
#   423,
#   45,
#   1422,
#   2,
#   4299,
#   14721,
#   3,
#   579,
#   638,
#   209,
#   91,
#   5,
#   17,
#   452,
#   1085,
#   28,
#   64,
#   61,
#   93,
#   2,
#   6,
#   8,
#   438,
#   568,
#   227],
#  [2753, 3670, 2817, 428, 178, 871, 3670, 98, 19014, 19015],
#  [727, 106, 512, 174, 252, 6, 590],
#  [6, 1011, 759, 3, 383, 447, 2111],
#  [273, 9, 2740],
#  [268,
#   278,
#   819,
#   269,
#   268,
#   2590,
#   790,
#   130,
#   26,
#   52,
#   13,
#   139,
#   18273,
#   538,
#   954,
#   11,
#   5057,
#   26,
#   331,
#   106,
#   3775,
#   36,
#   6830,
#   813,
#   10,
#   1095,
#   20,
#   4],
#  [20, 445],
#  [104,
#   379,
#   5784,
#   14722,
#   5472,
#   1839,
#   12,
#   1603,
#   113,
#   47,
#   119,
#   46,
#   5784,
#   14722,
#   5472,
#   680,
#   199,
#   1000,
#   6608,
#   31,
#   596,
#   2020,
#   2179,
#   341,
#   1349,
#   276,
#   61,
#   21,
#   7773,
#   438,
#   920,
#   371,
#   40,
#   158,
#   31,
#   200,
#   379,
#   957,
#   404,
#   2670,
#   104,
#   303,
#   11212,
#   16031,
#   6,
#   350,
#   102,
#   7773,
#   977,
#   3178,
#   145,
#   28,
#   23,
#   243,
#   256,
#   119,
#   5472,
#   680,
#   873,
#   11,
#   47,
#   581,
#   368,
#   6,
#   152,
#   4,
#   343,
#   2088,
#   591,
#   87],
#  [7703,
#   1048,
#   97,
#   394,
#   391,
#   6402,
#   5254,
#   12280,
#   3,
#   1078,
#   996,
#   1569,
#   1048,
#   97,
#   394,
#   208,
#   6929,
#   1709,
#   250,
#   73,
#   412,
#   157,
#   1076,
#   5,
#   36,
#   75,
#   217,
#   1739,
#   80,
#   847,
#   75,
#   28,
#   6762,
#   2,
#   20],
#  [510, 164, 61, 9, 219, 4],
#  [7, 9633, 66, 1354, 4945, 6178, 3334, 2345, 2607, 518],
#  [722,
#   1987,
#   1,
#   642,
#   1987,
#   6,
#   1664,
#   2401,
#   998,
#   1179,
#   25,
#   1088,
#   1971,
#   702,
#   533,
#   1987,
#   135,
#   8545,
#   11796,
#   611,
#   483,
#   616,
#   208,
#   2646,
#   5945,
#   85,
#   1102,
#   8855,
#   3444,
#   698,
#   497,
#   4913,
#   599,
#   25,
#   350,
#   1,
#   834,
#   68,
#   1987],
#  [20,
#   9,
#   1982,
#   226,
#   515,
#   3,
#   122,
#   135,
#   14,
#   1449,
#   1392,
#   8546,
#   7,
#   80,
#   347,
#   3671,
#   692,
#   201,
#   246,
#   104,
#   1182,
#   449,
#   120,
#   40,
#   52,
#   955,
#   1251,
#   5639,
#   51,
#   17,
#   261,
#   764,
#   6497,
#   101,
#   68,
#   54,
#   9396,
#   1671,
#   1,
#   59,
#   365,
#   369,
#   6497,
#   3324,
#   3928,
#   764,
#   4464,
#   1627,
#   9396,
#   1671,
#   7704,
#   5824,
#   4],
#  [81, 20, 308, 280, 9, 204, 4],
#  [13345, 10705, 2638, 484, 7933, 10705, 250, 272, 208, 5430],
#  [20, 48, 95, 2019, 462, 224, 114, 15, 373, 3865, 101, 1327, 15, 373, 4],
#  [72,
#   59,
#   22,
#   516,
#   693,
#   388,
#   2068,
#   12,
#   241,
#   235,
#   1264,
#   417,
#   177,
#   516,
#   22,
#   7,
#   828,
#   496,
#   2969,
#   4003],
#  [95, 15, 974, 3376, 3984, 1107],
#  [186, 289, 954, 89, 6930, 89, 89],
#  [105, 115, 7, 129, 101, 2, 14004, 924],
#  [27,
#   444,
#   331,
#   2707,
#   397,
#   7,
#   1830,
#   355,
#   15,
#   46,
#   15,
#   4,
#   2,
#   331,
#   2707,
#   1153,
#   397,
#   7,
#   1830,
#   15,
#   5109,
#   3915,
#   331,
#   1153,
#   2707,
#   11595,
#   1132,
#   562,
#   65,
#   100,
#   6543,
#   197,
#   5255,
#   4967,
#   2970],
#  [2, 246, 1026, 9176, 621, 5153, 202],
#  [4791, 19016, 1136],
#  [1905,
#   11,
#   75,
#   622,
#   692,
#   1,
#   267,
#   135,
#   185,
#   86,
#   4424,
#   1894,
#   75,
#   15578,
#   672,
#   8,
#   194,
#   1402,
#   1,
#   350,
#   843,
#   410,
#   1302,
#   6544,
#   887,
#   10323,
#   1702,
#   1702,
#   1267,
#   887,
#   31,
#   1,
#   1,
#   227,
#   75,
#   14,
#   52,
#   921,
#   1331,
#   1,
#   163,
#   10,
#   352,
#   2277,
#   229,
#   42,
#   352,
#   2277,
#   972,
#   8,
#   14368,
#   536,
#   227,
#   540,
#   1713,
#   929,
#   50,
#   541,
#   693,
#   52,
#   633,
#   7,
#   352,
#   410,
#   1302],
#  [531,
#   14369,
#   3050,
#   3672,
#   1990,
#   147,
#   5,
#   1276,
#   451,
#   2,
#   384,
#   530,
#   113,
#   128,
#   4,
#   360,
#   44,
#   636,
#   4,
#   6,
#   1295,
#   289,
#   182,
#   98,
#   222,
#   19017,
#   19018,
#   470,
#   459,
#   3577,
#   5678,
#   59,
#   250,
#   13,
#   1001,
#   6545,
#   121,
#   30,
#   58,
#   501,
#   161,
#   914,
#   6222,
#   10,
#   1379,
#   154,
#   1036,
#   9,
#   80],
#  [12, 1487, 12, 975, 322, 329, 4019, 11, 12, 1487, 401, 190],
#  [93,
#   3,
#   9177,
#   4402,
#   3759,
#   227,
#   1296,
#   200,
#   4282,
#   9177,
#   4402,
#   3759,
#   227,
#   1296,
#   200,
#   4282],
#  [326, 340, 272, 10706, 1, 78, 713, 228],
#  [102, 26, 1517, 258, 4],
#  [4371,
#   1168,
#   1260,
#   1180,
#   187,
#   1,
#   123,
#   103,
#   14,
#   160,
#   19792,
#   383,
#   1191,
#   6,
#   1310,
#   272,
#   875,
#   10507,
#   1640,
#   875,
#   11038,
#   10507,
#   4968,
#   21,
#   4946,
#   569,
#   4968,
#   1300,
#   752,
#   1537,
#   397,
#   9769,
#   210,
#   103,
#   2478,
#   832,
#   1,
#   17640,
#   6269,
#   420,
#   3011,
#   550,
#   6,
#   46,
#   2263,
#   738,
#   800,
#   12,
#   2278,
#   1848,
#   14,
#   2158,
#   4689,
#   14723,
#   217,
#   1],
#  [20,
#   5037,
#   2747,
#   5431,
#   838,
#   1776,
#   1465,
#   194,
#   7,
#   1988,
#   23,
#   550,
#   3134,
#   59,
#   6996,
#   19,
#   6609,
#   9397,
#   7632,
#   12553,
#   975,
#   5505,
#   53,
#   2015,
#   4055,
#   361,
#   1451,
#   19,
#   8,
#   120,
#   1279,
#   2402,
#   137,
#   118,
#   759,
#   914,
#   62,
#   16,
#   25],
#  [152,
#   8081,
#   1752,
#   143,
#   5110,
#   1491,
#   5858,
#   158,
#   196,
#   161,
#   95,
#   261,
#   3312,
#   261,
#   275,
#   3479,
#   16553,
#   3953,
#   3093,
#   8081,
#   1752,
#   595,
#   3121,
#   236,
#   8254,
#   7,
#   492,
#   3011,
#   816,
#   308,
#   8547,
#   4773,
#   4182,
#   12023,
#   202,
#   694,
#   3953,
#   18,
#   313,
#   3233,
#   202,
#   451,
#   1934,
#   147,
#   95,
#   1092,
#   9898,
#   4043,
#   492,
#   112,
#   158,
#   64,
#   3953,
#   56,
#   8081,
#   3051,
#   170,
#   5785,
#   3776,
#   1752,
#   1953,
#   583,
#   3953,
#   5220,
#   306,
#   2228,
#   217,
#   59,
#   2518,
#   2448,
#   3633,
#   147,
#   3953,
#   2037,
#   10707,
#   1735,
#   4146,
#   9898,
#   190,
#   17641,
#   8081,
#   1752,
#   6313,
#   19019,
#   977,
#   8081,
#   1752,
#   5110,
#   6313,
#   412,
#   397,
#   7,
#   302,
#   733,
#   6313,
#   153,
#   11396,
#   151,
#   3953,
#   471,
#   48,
#   56,
#   232,
#   100,
#   8081,
#   1752,
#   210,
#   7,
#   17642,
#   21,
#   964,
#   6831,
#   685,
#   156,
#   203,
#   1278,
#   115],
#  [10, 11, 19020, 15139, 232, 3, 2],
#  [9514,
#   163,
#   1325,
#   106,
#   336,
#   3040,
#   8980,
#   1675,
#   18,
#   996,
#   19,
#   1078,
#   3511,
#   408,
#   2953,
#   914,
#   1,
#   151,
#   454,
#   4852,
#   73,
#   195,
#   46,
#   654,
#   226,
#   3369,
#   858,
#   951,
#   8437,
#   1471,
#   1125,
#   307,
#   58,
#   1303,
#   188,
#   1471,
#   460,
#   853,
#   184,
#   2184,
#   151,
#   69,
#   172,
#   435,
#   4890,
#   2,
#   435,
#   4020],
#  [10, 9, 105, 1415, 89, 6546, 11397, 11213, 8082, 448],
#  [2206,
#   2904,
#   420,
#   7198,
#   101,
#   3302,
#   5,
#   64,
#   876,
#   1644,
#   2017,
#   43,
#   8343,
#   534,
#   564,
#   2017,
#   430,
#   4425,
#   48,
#   25,
#   4914,
#   2017,
#   571,
#   3061,
#   4],
#  [9398, 24, 7, 91],
#  [71,
#   53,
#   4056,
#   91,
#   1617,
#   288,
#   876,
#   2971,
#   197,
#   194,
#   53,
#   444,
#   4,
#   2,
#   3602,
#   145,
#   445,
#   794,
#   13,
#   368,
#   867],
#  [5280,
#   18,
#   1689,
#   1,
#   235,
#   283,
#   5280,
#   441,
#   31,
#   2905,
#   1694,
#   1915,
#   2905,
#   1682,
#   2810,
#   41,
#   1177],
#  [81,
#   35,
#   3,
#   62,
#   462,
#   4201,
#   751,
#   25,
#   512,
#   968,
#   651,
#   1392,
#   968,
#   4354,
#   1077,
#   45,
#   631,
#   79,
#   160,
#   4354],
#  [42, 73, 557, 2584, 465, 8171, 70, 89, 1540, 262, 4774, 1782, 2395, 644],
#  [452, 64, 300, 452, 175, 136, 103, 496, 2140, 343, 87],
#  [5432, 262, 654, 2591, 1350, 3091, 218, 61, 262, 8255, 106, 31],
#  [8548,
#   183,
#   16554,
#   4147,
#   1026,
#   734,
#   10185,
#   6071,
#   1416,
#   1,
#   8438,
#   3,
#   16554,
#   171,
#   6873,
#   1952,
#   4690,
#   47,
#   3234,
#   1218,
#   1234,
#   957,
#   797,
#   512,
#   783,
#   156,
#   937,
#   137,
#   19793,
#   1026,
#   6873,
#   16554,
#   239,
#   16554,
#   71,
#   171,
#   6873,
#   357,
#   8344,
#   509,
#   619,
#   98,
#   16555,
#   117,
#   18,
#   16554,
#   47,
#   151,
#   236,
#   929,
#   1203,
#   6663,
#   8549,
#   16554,
#   336,
#   521,
#   10506,
#   979,
#   48,
#   5128,
#   336,
#   547,
#   16554,
#   1066,
#   3634,
#   7837,
#   7841,
#   71,
#   504,
#   16554,
#   1358,
#   3092,
#   577,
#   171,
#   245,
#   14,
#   5605,
#   5946,
#   151,
#   161,
#   86,
#   547,
#   156,
#   161,
#   512,
#   16554,
#   547,
#   151,
#   929,
#   382,
#   6873,
#   4526,
#   19,
#   261,
#   16554,
#   6547,
#   180,
#   5473,
#   322,
#   7398,
#   952,
#   261,
#   117,
#   1861,
#   5606,
#   12281,
#   1869,
#   10,
#   785,
#   1479,
#   229,
#   3164,
#   479,
#   618,
#   86,
#   741,
#   6179,
#   952,
#   277,
#   1398,
#   932,
#   3179,
#   11398,
#   8345,
#   1769,
#   2255,
#   16554,
#   7548,
#   287,
#   16554,
#   3967,
#   2169,
#   5679,
#   64,
#   987,
#   1947,
#   4691,
#   740,
#   7548,
#   17643,
#   16554,
#   3967,
#   4106,
#   10324,
#   485,
#   2747,
#   302,
#   733,
#   741,
#   19794,
#   2011,
#   19,
#   86,
#   95,
#   24,
#   265,
#   161,
#   16554,
#   47,
#   1412,
#   14,
#   472,
#   123,
#   1386,
#   12806,
#   5038,
#   16554,
#   4546,
#   1468,
#   171,
#   1014,
#   171,
#   7548,
#   4202,
#   275,
#   16554,
#   2051,
#   4465,
#   3128,
#   840,
#   1343,
#   4148,
#   5859,
#   14724,
#   530,
#   412,
#   5395,
#   218,
#   658,
#   95,
#   47,
#   14,
#   7633,
#   7634,
#   441,
#   5256,
#   200,
#   290,
#   14,
#   350,
#   47,
#   1398,
#   932,
#   2073,
#   40,
#   187,
#   2718,
#   11214,
#   5315,
#   14005,
#   19,
#   485,
#   844,
#   472,
#   1280,
#   667,
#   16554,
#   3796,
#   1691,
#   659,
#   16554,
#   1811,
#   1248,
#   586,
#   4561,
#   357,
#   2025,
#   1695,
#   47,
#   4775,
#   2894,
#   1557,
#   2207,
#   485,
#   16554,
#   441,
#   16554,
#   3967,
#   1093,
#   5901],
#  [319, 2213, 3661, 2099, 10040, 2, 1578, 91, 1542, 6358, 1578, 2, 702, 877, 4],
#  [2134,
#   1002,
#   423,
#   17644,
#   3313,
#   71,
#   5039,
#   8981,
#   6997,
#   762,
#   9,
#   1252,
#   7841,
#   842,
#   1716,
#   1700,
#   3303,
#   1097,
#   190,
#   9899,
#   116],
#  [309,
#   3850,
#   14725,
#   1745,
#   1645,
#   5080,
#   3850,
#   14725,
#   1745,
#   1203,
#   5035,
#   807,
#   1745,
#   5154,
#   3,
#   1,
#   48,
#   4340,
#   323,
#   10041,
#   5035,
#   8662,
#   74,
#   161,
#   163,
#   10186,
#   1745,
#   463,
#   1289,
#   5035,
#   8662,
#   276,
#   78,
#   34,
#   311,
#   1289,
#   46,
#   5035,
#   8662,
#   1745,
#   1730,
#   961],
#  [162,
#   1345,
#   161,
#   3480,
#   1437,
#   1689,
#   1240,
#   2,
#   412,
#   1839,
#   21,
#   269,
#   795,
#   1170,
#   1200,
#   14726,
#   11797,
#   11399,
#   250],
#  [9286, 52, 233, 9286, 153, 3369, 9286, 7, 3235, 120, 97, 541, 94, 1],
#  [27,
#   65,
#   232,
#   2543,
#   1321,
#   606,
#   139,
#   225,
#   74,
#   22,
#   2831,
#   7705,
#   2235,
#   3377,
#   3120,
#   453,
#   1880,
#   3865,
#   3647,
#   260,
#   654,
#   15,
#   66,
#   106,
#   280,
#   56,
#   17645,
#   16032],
#  [335,
#   1144,
#   1004,
#   2329,
#   134,
#   65,
#   11,
#   1961,
#   4021,
#   5001,
#   339,
#   7635,
#   201,
#   1028,
#   221,
#   65,
#   56],
#  [53,
#   40,
#   1,
#   352,
#   83,
#   683,
#   3,
#   16,
#   66,
#   6,
#   177,
#   54,
#   415,
#   1491,
#   5534,
#   484,
#   450,
#   206,
#   3729,
#   26,
#   36,
#   2074,
#   888,
#   136,
#   116,
#   604,
#   366,
#   259,
#   2283,
#   82,
#   1997,
#   593,
#   10,
#   316,
#   3818,
#   122,
#   19021,
#   1457,
#   25,
#   161,
#   3662,
#   459,
#   30,
#   153,
#   104,
#   954,
#   13,
#   24,
#   1507,
#   216,
#   951,
#   1003,
#   190,
#   104,
#   190,
#   813],
#  [134,
#   404,
#   490,
#   1,
#   14727,
#   3170,
#   397,
#   6122,
#   4756,
#   1,
#   3777,
#   1,
#   988,
#   550,
#   1453,
#   18,
#   343],
#  [681, 493, 1020, 79, 96, 7399, 16033, 599],
#  [11,
#   18,
#   388,
#   22,
#   106,
#   780,
#   1327,
#   12,
#   388,
#   804,
#   17,
#   1310,
#   287,
#   7,
#   28,
#   186,
#   34,
#   114],
#  [4637, 4637],
#  [3683, 11215, 40, 1341],
#  [4044,
#   1826,
#   922,
#   489,
#   87,
#   4300,
#   375,
#   495,
#   2608,
#   495,
#   90,
#   40,
#   3129,
#   148,
#   7199,
#   1782,
#   3355,
#   323,
#   1919,
#   214,
#   109,
#   304,
#   31,
#   1149,
#   73,
#   137,
#   14,
#   3094,
#   35,
#   2100,
#   2608,
#   1111,
#   7200,
#   3024,
#   16034,
#   3796,
#   2100,
#   9515,
#   2318,
#   16556,
#   1695,
#   1811,
#   6359,
#   9516,
#   3032,
#   8256,
#   485,
#   6874,
#   3033,
#   35,
#   2801,
#   13346,
#   658,
#   2614,
#   11400,
#   196,
#   506,
#   4831,
#   341,
#   14006,
#   7774,
#   627,
#   2340,
#   2608,
#   506,
#   11400,
#   748,
#   479,
#   2100,
#   3402,
#   2818,
#   1249,
#   361,
#   40,
#   3189,
#   2205,
#   484,
#   2427,
#   5860,
#   3024,
#   861],
#  [35,
#   705,
#   4915,
#   7075,
#   4403,
#   35,
#   7075,
#   705,
#   4915,
#   1888,
#   1996,
#   813,
#   291,
#   4224,
#   5,
#   9,
#   3,
#   4320,
#   4915,
#   1888,
#   1996,
#   2591,
#   4915,
#   3222,
#   691,
#   10,
#   6,
#   8,
#   3025,
#   127,
#   1438,
#   347,
#   4,
#   2,
#   3,
#   4320,
#   4915,
#   20],
#  [507,
#   6,
#   231,
#   18274,
#   280,
#   8083,
#   267,
#   6,
#   8,
#   233,
#   378,
#   46,
#   4,
#   1147,
#   331,
#   10,
#   1232,
#   331,
#   2707,
#   231,
#   478,
#   280,
#   72,
#   1183,
#   250,
#   24,
#   405,
#   67,
#   182,
#   2034,
#   3528,
#   540,
#   16,
#   160,
#   769,
#   44,
#   676,
#   1292,
#   3,
#   259,
#   7,
#   208,
#   883,
#   724,
#   495,
#   165,
#   16,
#   3209,
#   271,
#   78,
#   5861,
#   15,
#   373,
#   277,
#   3,
#   259,
#   229,
#   405,
#   676,
#   676,
#   191,
#   4832,
#   16035,
#   16,
#   4692,
#   672,
#   152,
#   935,
#   46,
#   545,
#   122,
#   935,
#   163,
#   71,
#   2586,
#   771,
#   71,
#   935,
#   368,
#   826,
#   2034,
#   351,
#   4832,
#   261,
#   140,
#   740,
#   12282,
#   969,
#   50,
#   1292,
#   82,
#   15,
#   16,
#   486,
#   754,
#   5575,
#   6,
#   8,
#   233,
#   110,
#   6,
#   235,
#   95,
#   358,
#   717,
#   1512,
#   383,
#   5358,
#   737,
#   1687,
#   43,
#   18274,
#   19022,
#   1076,
#   107,
#   1264,
#   676,
#   767,
#   43,
#   10042,
#   18,
#   366,
#   72,
#   74,
#   220,
#   18,
#   325,
#   5,
#   23,
#   1264,
#   380,
#   259,
#   1082,
#   231,
#   153,
#   1911,
#   39,
#   104,
#   379,
#   6403,
#   614,
#   897,
#   72,
#   23,
#   96,
#   380,
#   10325,
#   6548,
#   1978,
#   778,
#   20],
#  [1003,
#   2880,
#   4,
#   14,
#   940,
#   6998,
#   5,
#   136,
#   119,
#   4,
#   2,
#   15140,
#   72,
#   59,
#   601,
#   186,
#   609,
#   15,
#   170,
#   2,
#   7934,
#   190,
#   3413,
#   19023,
#   1078,
#   47,
#   3095,
#   1569,
#   20,
#   44],
#  [84, 81, 1044, 1560, 16557, 15579, 12554, 84, 20],
#  [198,
#   5,
#   11401,
#   1395,
#   1815,
#   23,
#   104,
#   1858,
#   71,
#   589,
#   18,
#   684,
#   36,
#   10864,
#   205,
#   10,
#   115,
#   2403,
#   1375,
#   508,
#   462,
#   15,
#   948,
#   7,
#   671,
#   180,
#   1191,
#   15,
#   948,
#   301,
#   493,
#   23,
#   77,
#   18,
#   10,
#   110,
#   133,
#   1396,
#   309,
#   46,
#   4,
#   2,
#   166,
#   8435,
#   12555,
#   482,
#   2044,
#   93,
#   150,
#   1008,
#   17646,
#   671,
#   27,
#   1082,
#   1578,
#   504,
#   9634,
#   900,
#   1275,
#   11596,
#   3312,
#   5359,
#   348,
#   4562,
#   870,
#   20],
#  [6610, 1493],
#  [3730,
#   183,
#   3730,
#   108,
#   11039,
#   582,
#   39,
#   743,
#   369,
#   35,
#   70,
#   172,
#   150,
#   18,
#   65,
#   4,
#   2,
#   45],
#  [109,
#   64,
#   19,
#   137,
#   262,
#   255,
#   238,
#   5129,
#   5902,
#   5535,
#   4341,
#   6404,
#   908,
#   5316,
#   6,
#   8982,
#   4129,
#   157,
#   525,
#   50,
#   157,
#   1029,
#   3062,
#   2954,
#   772,
#   73,
#   2637,
#   4969,
#   624,
#   1835,
#   9287],
#  [53,
#   311,
#   82,
#   3819,
#   9399,
#   1937,
#   147,
#   7549,
#   14728,
#   2426,
#   460,
#   624,
#   28,
#   320,
#   6931,
#   3286,
#   7549,
#   7,
#   867,
#   1890,
#   7,
#   21,
#   134,
#   1985,
#   624,
#   402,
#   6123,
#   1384,
#   2356,
#   66,
#   867,
#   22,
#   2291,
#   66,
#   22,
#   31,
#   83,
#   123,
#   7076],
#  [67,
#   246,
#   2284,
#   10043,
#   1086,
#   7269,
#   655,
#   34,
#   2221,
#   6314,
#   1027,
#   122,
#   14,
#   658,
#   1201,
#   366,
#   153,
#   2285,
#   3601,
#   2241,
#   1163,
#   14,
#   658,
#   366,
#   299,
#   2221,
#   1183,
#   17073,
#   5317,
#   2242,
#   368,
#   1116,
#   17073,
#   242,
#   24,
#   856,
#   2811,
#   203,
#   17073,
#   1789,
#   229,
#   836,
#   3760,
#   685,
#   627,
#   2221,
#   305,
#   48,
#   104,
#   5081,
#   6498,
#   24,
#   493,
#   23,
#   96,
#   101,
#   2302,
#   282,
#   3542,
#   2221,
#   2584,
#   83,
#   3,
#   31],
#  [162,
#   7,
#   239,
#   71,
#   699,
#   245,
#   7,
#   226,
#   291,
#   299,
#   4970,
#   2404,
#   9770,
#   4072,
#   1874,
#   4916,
#   304,
#   4130,
#   41,
#   272,
#   2231,
#   5221,
#   4724,
#   416,
#   846,
#   83,
#   749,
#   10,
#   135,
#   74,
#   1353,
#   321,
#   473,
#   321,
#   416,
#   1607,
#   1508,
#   6072,
#   8,
#   9771,
#   7,
#   5155],
#  [4372, 263, 17074, 6124, 263],
#  [5536,
#   311,
#   2006,
#   1,
#   4563,
#   2261,
#   12556,
#   1909,
#   2311,
#   1168,
#   10,
#   157,
#   1,
#   891,
#   4563,
#   2261,
#   1145,
#   8439,
#   529,
#   226,
#   182,
#   2816,
#   229,
#   405,
#   357,
#   258,
#   386,
#   386,
#   6180,
#   6,
#   56,
#   4563,
#   2261,
#   1145,
#   8439,
#   1,
#   142,
#   1020,
#   67,
#   16,
#   4610],
#  [4693, 1320, 112, 8550, 4564, 2412, 321, 555],
#  [753,
#   86,
#   705,
#   2105,
#   147,
#   1395,
#   851,
#   423,
#   147,
#   347,
#   2105,
#   18,
#   62,
#   147,
#   132,
#   1077,
#   439,
#   315,
#   4321,
#   289,
#   70,
#   20],
#  [592, 2207, 436, 323, 181, 1328, 2570, 502, 1677, 196, 587, 99],
#  [197,
#   1608,
#   2360,
#   289,
#   103,
#   2708,
#   516,
#   132,
#   5,
#   101,
#   197,
#   9288,
#   516,
#   551,
#   294,
#   632,
#   197,
#   3797,
#   4283,
#   502,
#   5,
#   186,
#   1110,
#   12283,
#   39,
#   4694,
#   592,
#   197],
#  [1889,
#   1619,
#   15,
#   801,
#   1619,
#   15,
#   207,
#   848,
#   360,
#   2,
#   1029,
#   51,
#   4094,
#   12284,
#   3968,
#   2697,
#   1],
#  [592, 120, 22, 5082, 700, 4662, 59, 128, 1380],
#  [10508,
#   15580,
#   6930,
#   3403,
#   1333,
#   754,
#   9517,
#   5947,
#   497,
#   3985,
#   6930,
#   10508,
#   521,
#   3275,
#   5786,
#   1803,
#   18,
#   2386,
#   1670,
#   249,
#   1816,
#   5396,
#   542,
#   18,
#   2839,
#   7,
#   521,
#   180,
#   7270,
#   95,
#   540,
#   521,
#   15580,
#   1752,
#   2179,
#   1032,
#   3778,
#   498,
#   1391,
#   733,
#   8003,
#   487,
#   7201,
#   733,
#   2089,
#   2236,
#   1759,
#   3445,
#   733,
#   501,
#   771,
#   542,
#   448,
#   5002,
#   118,
#   88,
#   5607,
#   9517,
#   3929,
#   2112,
#   1032,
#   13073,
#   7201,
#   376,
#   336,
#   85,
#   1759,
#   376,
#   13073,
#   14370,
#   18,
#   1647,
#   1759,
#   598,
#   9517,
#   10,
#   2955,
#   8003,
#   1759,
#   2895,
#   2955,
#   18,
#   311,
#   73,
#   179,
#   3121,
#   8003,
#   166,
#   1450,
#   311,
#   18275,
#   8003,
#   598,
#   10,
#   21,
#   3063,
#   8003,
#   754,
#   1205,
#   2896,
#   598,
#   4695,
#   208,
#   18,
#   392,
#   1745,
#   758,
#   6549,
#   27,
#   336,
#   4426,
#   3069,
#   4776,
#   336,
#   85,
#   3063,
#   754,
#   758,
#   160,
#   758,
#   4777,
#   2653,
#   1145,
#   14,
#   1069,
#   298,
#   1333,
#   1145,
#   754,
#   410,
#   311,
#   18275,
#   761,
#   2325,
#   1759,
#   2097,
#   383,
#   498,
#   31,
#   10,
#   8003,
#   1759,
#   2787,
#   1196,
#   14370,
#   26,
#   311,
#   1759,
#   2097,
#   761,
#   498,
#   8003,
#   598,
#   10,
#   311,
#   4022,
#   598,
#   1145,
#   14,
#   8003,
#   754,
#   930,
#   1333,
#   1145,
#   754,
#   121,
#   208,
#   31,
#   376,
#   8003,
#   1070,
#   376,
#   2647,
#   4611,
#   3503,
#   4225,
#   3129,
#   952,
#   1069,
#   123,
#   1145,
#   994,
#   298,
#   789,
#   358,
#   534,
#   2819,
#   1145,
#   1205,
#   1032,
#   8003,
#   1759,
#   200,
#   9,
#   791,
#   9,
#   67,
#   157,
#   4199,
#   67,
#   157,
#   156,
#   135,
#   4199,
#   10187,
#   383,
#   465,
#   7550,
#   19024,
#   1032,
#   27,
#   311,
#   47,
#   3745,
#   1677,
#   587,
#   738,
#   383,
#   1594,
#   733,
#   487,
#   1032,
#   2151,
#   4793,
#   8172,
#   536,
#   4199,
#   586,
#   1113,
#   1767,
#   5948,
#   226,
#   3612,
#   34,
#   2647,
#   501,
#   771,
#   1816,
#   18,
#   1915,
#   329,
#   299,
#   2647,
#   282,
#   7400,
#   733,
#   2647,
#   2089,
#   2236,
#   7935,
#   202,
#   598,
#   9517,
#   1205,
#   598,
#   487,
#   7201,
#   733,
#   4583,
#   2647,
#   13074,
#   9900,
#   7842,
#   12807,
#   7401,
#   12807,
#   6549,
#   5948,
#   11597,
#   7401,
#   5948,
#   8003,
#   754,
#   5111,
#   8003,
#   754,
#   510,
#   2230,
#   733,
#   8983,
#   4527,
#   12557,
#   151,
#   11597,
#   1472,
#   1786,
#   2089,
#   18276,
#   290,
#   5948,
#   3982,
#   35,
#   1145,
#   1032,
#   8003,
#   1759,
#   200,
#   1260,
#   1205,
#   94,
#   921,
#   6930,
#   716,
#   46,
#   2727,
#   6360,
#   574,
#   4971,
#   1148,
#   87],
#  [109,
#   930,
#   1104,
#   585,
#   2748,
#   3378,
#   585,
#   2989,
#   534,
#   336,
#   3426,
#   141,
#   4638,
#   6875,
#   221,
#   147,
#   27,
#   13,
#   221,
#   764,
#   667,
#   17075,
#   135],
#  [26,
#   5397,
#   1072,
#   4,
#   2,
#   295,
#   793,
#   63,
#   11039,
#   20,
#   491,
#   8004,
#   2105,
#   147,
#   126,
#   10188,
#   9518,
#   9289,
#   1553,
#   2671,
#   1655,
#   2029,
#   2116,
#   991,
#   1185,
#   1315,
#   1470,
#   1106,
#   544,
#   1790,
#   15581,
#   1225,
#   4892,
#   2708,
#   182,
#   834,
#   315,
#   3,
#   4166,
#   6718,
#   7636,
#   3673,
#   7,
#   13,
#   113,
#   42,
#   977,
#   22,
#   900,
#   110,
#   7,
#   488,
#   785,
#   10865,
#   315,
#   48,
#   7,
#   117,
#   173,
#   42,
#   785,
#   316,
#   497,
#   1686,
#   2081,
#   97,
#   834,
#   785,
#   164,
#   347,
#   587,
#   3969,
#   3969,
#   10326,
#   1225,
#   5903,
#   4639,
#   182,
#   8856,
#   14007,
#   368,
#   7637,
#   3969,
#   611,
#   10044,
#   142,
#   1866,
#   2466,
#   3969,
#   8551,
#   94,
#   35,
#   1077,
#   8004,
#   2105,
#   434,
#   148,
#   8346,
#   1947,
#   2747,
#   125,
#   8,
#   492,
#   279,
#   1046,
#   59,
#   1947,
#   2747,
#   936,
#   313,
#   67,
#   986,
#   2919,
#   3761,
#   2747,
#   10,
#   1811,
#   8346,
#   1947,
#   581,
#   321,
#   745,
#   407,
#   2671,
#   1655,
#   3366,
#   2116,
#   991,
#   1185,
#   1470,
#   1553,
#   6405,
#   4149,
#   3379,
#   1185,
#   148,
#   5433,
#   2747,
#   390,
#   1100,
#   3489,
#   544,
#   439,
#   7074,
#   1431,
#   7133,
#   5318,
#   1001,
#   713,
#   279,
#   2006,
#   3041,
#   1881,
#   821,
#   35,
#   1100,
#   3041,
#   1881,
#   74,
#   7,
#   928,
#   19,
#   6932,
#   1457,
#   581,
#   5537,
#   44,
#   124,
#   943,
#   37,
#   99,
#   3828,
#   35,
#   1214,
#   1795,
#   9519,
#   584,
#   8004,
#   368,
#   7077,
#   3699,
#   282,
#   3276,
#   2151,
#   6932,
#   845,
#   439,
#   2704,
#   8346,
#   1947,
#   74,
#   584,
#   1894,
#   8346,
#   1947,
#   139,
#   28,
#   1670,
#   1341],
#  [258, 404, 1312, 5, 6448, 258],
#  [1092, 2548, 51, 761, 281, 1096, 609, 955, 665, 633, 103, 337],
#  [9290,
#   682,
#   1255,
#   343,
#   87,
#   1003,
#   113,
#   128,
#   172,
#   231,
#   4,
#   2,
#   41,
#   36,
#   114,
#   179,
#   387,
#   42,
#   183],
#  [306,
#   1027,
#   15582,
#   416,
#   7,
#   1162,
#   372,
#   255,
#   2979,
#   2522,
#   1027,
#   1971,
#   2728,
#   132,
#   597,
#   192,
#   3335,
#   102,
#   187,
#   194,
#   2431,
#   295,
#   981,
#   1595,
#   459,
#   4373,
#   1675,
#   964,
#   1509,
#   47,
#   159,
#   30,
#   1023,
#   2018,
#   3446,
#   3313,
#   16036,
#   2619,
#   736,
#   5281,
#   2376,
#   6550,
#   1582,
#   80,
#   16,
#   1504,
#   165,
#   930,
#   1104,
#   2113,
#   558,
#   38,
#   5222,
#   2432,
#   5281],
#  [81,
#   81,
#   24,
#   201,
#   18277,
#   1839,
#   46,
#   132,
#   46,
#   132,
#   201,
#   201,
#   398,
#   7,
#   1492,
#   398,
#   2289,
#   2614,
#   1399,
#   4264,
#   773,
#   5748,
#   5576,
#   779,
#   463,
#   18278,
#   201,
#   310,
#   503,
#   2850,
#   130,
#   239,
#   9,
#   13,
#   47,
#   130,
#   41,
#   727,
#   13,
#   546,
#   201,
#   804,
#   621,
#   559,
#   727,
#   509,
#   4696,
#   1839,
#   1155,
#   677,
#   714,
#   1157,
#   2233,
#   12,
#   2233,
#   434,
#   2325,
#   1083,
#   565,
#   7551,
#   201],
#  [2405, 72, 8347, 3127, 255, 276, 1817, 14, 8, 652, 156],
#  [418,
#   8,
#   1982,
#   4131,
#   415,
#   910,
#   120,
#   58,
#   67,
#   79,
#   604,
#   167,
#   1687,
#   3635,
#   31,
#   534,
#   1441,
#   363,
#   2897,
#   77,
#   3041,
#   1881,
#   28,
#   876,
#   31,
#   4],
#  [6449,
#   773,
#   15583,
#   7,
#   2678,
#   1043,
#   13,
#   12,
#   338,
#   206,
#   149,
#   927,
#   321,
#   908,
#   15141,
#   8749,
#   238,
#   155,
#   1308,
#   17647,
#   6449,
#   773,
#   8857,
#   8857,
#   9,
#   204,
#   12285],
#  [94, 452, 59, 97, 20],
#  [198,
#   580,
#   481,
#   13347,
#   3553,
#   58,
#   670,
#   11216,
#   11,
#   416,
#   240,
#   4355,
#   5787,
#   1879,
#   6315,
#   12558,
#   4183,
#   2073,
#   2760,
#   11216,
#   4584,
#   135,
#   1137,
#   13347,
#   4528,
#   7552,
#   1640,
#   2760,
#   943,
#   13347,
#   670,
#   4913,
#   1383,
#   13347],
#  [273, 13, 20],
#  [573, 5640, 48, 1293, 417, 627, 1305, 5, 260, 267, 114, 28, 60],
#  [13, 689],
#  [11, 19795, 22, 3779, 624, 251, 162, 105, 689, 12, 1408],
#  [1002, 18, 489],
#  [162, 70, 801, 909, 5257, 4893, 36, 213],
#  [507,
#   1322,
#   1948,
#   3866,
#   4167,
#   123,
#   7072,
#   2233,
#   199,
#   13,
#   4167,
#   123,
#   50,
#   123,
#   901,
#   11798,
#   215,
#   752,
#   354,
#   754,
#   242,
#   3529,
#   2387,
#   6999,
#   1083,
#   618,
#   6999,
#   1083,
#   2069,
#   5474,
#   3684,
#   1261,
#   5282,
#   1455,
#   8750,
#   1237,
#   14,
#   1157,
#   2183,
#   14,
#   53,
#   2555,
#   1354,
#   4167,
#   5749,
#   123,
#   2387,
#   11,
#   72,
#   7775,
#   2189,
#   718,
#   3026,
#   10509,
#   252,
#   213,
#   1237,
#   16558,
#   3,
#   361,
#   132,
#   31,
#   14,
#   219,
#   156,
#   11],
#  [1826,
#   729,
#   423,
#   1307,
#   144,
#   12559,
#   88,
#   4865,
#   49,
#   132,
#   79,
#   368,
#   2485,
#   2655,
#   1570,
#   11402,
#   625,
#   309,
#   444,
#   69,
#   25,
#   36,
#   2161,
#   14,
#   3144,
#   648,
#   4164,
#   12808,
#   25,
#   1,
#   6551,
#   6611,
#   19,
#   14729,
#   547,
#   15,
#   264,
#   50,
#   1805,
#   209,
#   974,
#   179,
#   5398,
#   25,
#   91,
#   883,
#   5003,
#   135,
#   2222,
#   3611,
#   309,
#   17648,
#   14730,
#   191,
#   25,
#   1099,
#   666,
#   625,
#   399,
#   2602,
#   684,
#   57,
#   103,
#   136,
#   34,
#   97,
#   80,
#   2361,
#   8984,
#   1069,
#   1376,
#   44,
#   5,
#   9,
#   15,
#   13348,
#   13,
#   3199,
#   171,
#   3829,
#   34,
#   1376,
#   132],
#  [447, 55, 3567, 602, 10708],
#  [16559, 623, 840, 11799, 4],
#  [35,
#   3730,
#   5283,
#   206,
#   5283,
#   559,
#   5283,
#   348,
#   39,
#   468,
#   5283,
#   5283,
#   621,
#   5283,
#   4972,
#   1043,
#   5283,
#   5283,
#   5283,
#   5283,
#   300,
#   635,
#   39,
#   4972],
#  [1148, 922, 343, 87, 4, 279, 6552, 1546, 43, 50],
#  [5, 519, 33, 15, 169, 76, 37, 7331],
#  [240, 909, 909, 95, 12809, 1355, 2733, 698, 271, 5473],
#  [1049, 2831, 145, 65, 2685, 337, 100, 5862],
#  [1215,
#   854,
#   1134,
#   3469,
#   3881,
#   6316,
#   89,
#   3,
#   1343,
#   126,
#   496,
#   1215,
#   854,
#   1134,
#   3469,
#   4973,
#   4184,
#   950,
#   7398,
#   379,
#   418,
#   199,
#   59,
#   11,
#   26,
#   1194,
#   725,
#   524,
#   222,
#   343,
#   5640],
#  [162,
#   16560,
#   12,
#   13669,
#   44,
#   34,
#   2580,
#   543,
#   33,
#   720,
#   36,
#   48,
#   237,
#   3543,
#   237,
#   323,
#   65,
#   308,
#   3530],
#  [848,
#   17,
#   180,
#   1344,
#   1387,
#   21,
#   8,
#   1637,
#   131,
#   9898,
#   7402,
#   19025,
#   542,
#   743,
#   1637,
#   7,
#   991,
#   7134,
#   7000,
#   5986,
#   743,
#   12286,
#   2388,
#   14371],
#  [476,
#   1624,
#   1,
#   1458,
#   892,
#   110,
#   222,
#   3403,
#   377,
#   253,
#   1624,
#   3762,
#   54,
#   918,
#   360,
#   2571,
#   6763,
#   4508,
#   353,
#   508,
#   3,
#   19,
#   14008,
#   440,
#   3762],
#  [82,
#   296,
#   2719,
#   687,
#   7403,
#   159,
#   459,
#   30,
#   26,
#   344,
#   218,
#   2433,
#   10709,
#   4185,
#   6,
#   22,
#   3165,
#   331,
#   30,
#   77,
#   15,
#   948,
#   547,
#   30,
#   4],
#  [17649, 582, 282],
#  [2720, 67, 1312, 14372, 951, 326],
#  [273,
#   10,
#   589,
#   1510,
#   891,
#   314,
#   4374,
#   6499,
#   291,
#   6223,
#   2,
#   1044,
#   276,
#   48,
#   329,
#   1401,
#   1882,
#   521,
#   1567,
#   4132,
#   1038,
#   440],
#  [260,
#   197,
#   81,
#   206,
#   8,
#   197,
#   260,
#   145,
#   107,
#   47,
#   456,
#   401,
#   2521,
#   12560,
#   12287,
#   10327,
#   5538,
#   517],
#  [1670,
#   13670,
#   982,
#   1,
#   114,
#   1731,
#   272,
#   4342,
#   8084,
#   2479,
#   3051,
#   6,
#   5313,
#   218,
#   332,
#   130,
#   2386,
#   501,
#   1038,
#   249,
#   262,
#   27,
#   1038,
#   174,
#   14,
#   738,
#   1442,
#   4565,
#   27,
#   4342,
#   12,
#   49,
#   1597,
#   3012,
#   4974,
#   742,
#   12,
#   241,
#   294,
#   72,
#   59,
#   308,
#   819,
#   14373],
#  [6876,
#   1930,
#   441,
#   428,
#   17076,
#   2217,
#   325,
#   1416,
#   933,
#   324,
#   31,
#   31,
#   200,
#   1138,
#   9400,
#   1365,
#   1412,
#   4690,
#   14,
#   2082,
#   6181,
#   8985,
#   3444,
#   4017,
#   5130,
#   1793,
#   6406,
#   3727,
#   31,
#   510,
#   5641,
#   646,
#   6034,
#   3389,
#   441,
#   31,
#   456,
#   882,
#   1234,
#   2204],
#  [1549, 1, 3578, 1219, 411, 264, 572, 8348, 12288],
#  [70,
#   14374,
#   455,
#   1,
#   180,
#   14374,
#   402,
#   90,
#   154,
#   402,
#   2150,
#   491,
#   417,
#   378,
#   17650,
#   62,
#   122,
#   11,
#   144,
#   596,
#   180,
#   14374,
#   814,
#   1331,
#   195,
#   1,
#   46,
#   70,
#   11,
#   70,
#   503,
#   24,
#   598,
#   939,
#   13,
#   6719,
#   218,
#   237,
#   1184,
#   14374,
#   114,
#   133,
#   70,
#   6,
#   8,
#   66,
#   1692,
#   149,
#   653],
#  [1579,
#   271,
#   1665,
#   859,
#   538,
#   46,
#   1045,
#   1870,
#   86,
#   1,
#   5949,
#   2351,
#   786,
#   271,
#   920,
#   86,
#   1,
#   86,
#   712,
#   103,
#   47,
#   14,
#   22,
#   3954,
#   9401,
#   3,
#   22,
#   9635,
#   200],
#  [159, 30, 664, 530, 5, 1204, 104, 1580, 1, 4],
#  [255,
#   45,
#   48,
#   2663,
#   1,
#   11,
#   18,
#   6317,
#   96,
#   2918,
#   293,
#   116,
#   54,
#   1055,
#   152,
#   14,
#   403,
#   593,
#   428,
#   809,
#   193,
#   453,
#   190],
#  [285,
#   6,
#   177,
#   340,
#   217,
#   3618,
#   3163,
#   1140,
#   144,
#   9520,
#   673,
#   2357,
#   2620,
#   6,
#   3070,
#   1,
#   6361,
#   10,
#   50,
#   1080,
#   539,
#   153,
#   11,
#   1867,
#   869,
#   25,
#   300,
#   285,
#   364,
#   299,
#   112,
#   505,
#   1111,
#   1034,
#   1187,
#   505,
#   210,
#   1889,
#   3531,
#   1707,
#   372,
#   5904,
#   1809,
#   120,
#   23,
#   102,
#   253,
#   4002,
#   4017],
#  [53,
#   4023,
#   131,
#   1338,
#   1173,
#   6933,
#   297,
#   3,
#   239,
#   100,
#   506,
#   571,
#   751,
#   3,
#   16,
#   2080,
#   868,
#   751,
#   2018,
#   8,
#   1005,
#   2090,
#   17077,
#   16,
#   223,
#   76,
#   502],
#  [149,
#   84,
#   431,
#   1781,
#   1703,
#   225,
#   142,
#   2329,
#   85,
#   105,
#   61,
#   225,
#   2101,
#   131,
#   1400,
#   4529,
#   21,
#   1,
#   4248,
#   3,
#   4794,
#   38,
#   227,
#   2038,
#   9080,
#   145,
#   15,
#   224,
#   460,
#   8,
#   9,
#   937,
#   1400,
#   2691,
#   1488,
#   80,
#   4248,
#   1649,
#   60,
#   3954,
#   2753],
#  [2706,
#   81,
#   65,
#   19,
#   224,
#   16,
#   15584,
#   11217,
#   754,
#   1177,
#   6,
#   3027,
#   1412,
#   4375,
#   1073,
#   8858,
#   125,
#   1229,
#   439,
#   120,
#   4376,
#   148,
#   51,
#   2732,
#   7271,
#   106,
# ...
#   68,
#   312,
#   2494,
#   730,
#   615,
#   305,
#   66,
#   262,
#   773,
#   4,
#   2,
#   102,
#   305,
#   1],
#  [20,
#   20,
#   4451,
#   3356,
#   17115,
#   5405,
#   2,
#   12,
#   381,
#   3194,
#   2,
#   5,
#   15,
#   20,
#   493,
#   40,
#   3215,
#   34,
#   927,
#   7715,
#   5960,
#   991,
#   5229,
#   1185,
#   17683,
#   8772,
#   14763,
#   8772,
#   11427,
#   15624,
#   5095,
#   1372,
#   10343,
#   1067,
#   3344,
#   19859,
#   7491,
#   1693,
#   927,
#   13092,
#   1067,
#   5960,
#   991,
#   5229,
#   5044,
#   1297,
#   7491,
#   1693,
#   927,
#   421,
#   6369,
#   1058,
#   473,
#   751,
#   44],
#  [14045,
#   14045,
#   2,
#   2397,
#   2305,
#   43,
#   10886,
#   13,
#   28,
#   1335,
#   666,
#   13,
#   611,
#   819,
#   434,
#   1329,
#   2637,
#   1086,
#   611,
#   101,
#   80,
#   11,
#   538,
#   164,
#   6568,
#   1040,
#   415,
#   48,
#   131,
#   1003,
#   252,
#   1620,
#   6944,
#   6944,
#   1066,
#   120,
#   894],
#  [8, 9, 2519, 57, 291, 333, 78, 2743],
#  [584,
#   29,
#   422,
#   289,
#   1165,
#   3,
#   50,
#   97,
#   5963,
#   3407,
#   212,
#   1095,
#   1,
#   18,
#   2419,
#   316,
#   264,
#   793,
#   29,
#   285,
#   344,
#   9,
#   10,
#   3,
#   316,
#   29,
#   122,
#   18,
#   1176,
#   584,
#   29,
#   351,
#   285,
#   5,
#   344,
#   596,
#   584,
#   29,
#   15,
#   373,
#   4,
#   2,
#   5,
#   256,
#   1374,
#   1,
#   283,
#   315,
#   1414,
#   21,
#   134,
#   351,
#   29,
#   285,
#   1176,
#   29,
#   584,
#   29,
#   422,
#   1,
#   18,
#   65,
#   54,
#   2384,
#   146,
#   29,
#   264,
#   936,
#   16,
#   29,
#   18,
#   54,
#   194,
#   193,
#   1402],
#  [5369, 31, 120, 9, 431, 1214, 7570],
#  [1, 129, 1140, 9, 2243],
#  [14764, 541, 877, 443, 428, 198],
#  [21,
#   304,
#   1,
#   288,
#   2980,
#   10887,
#   549,
#   38,
#   1,
#   1836,
#   131,
#   12049,
#   9307,
#   692,
#   9795,
#   3478,
#   10887,
#   529,
#   7950,
#   614,
#   21,
#   1301,
#   186,
#   293,
#   48,
#   323,
#   61,
#   2466,
#   7548,
#   21,
#   594,
#   159,
#   690,
#   30,
#   138,
#   10,
#   2560,
#   1118,
#   559,
#   1546,
#   16597,
#   1594,
#   485,
#   21,
#   7548,
#   3672,
#   3453,
#   2122,
#   748,
#   18329,
#   1432,
#   378,
#   46,
#   10887,
#   288,
#   99,
#   7724,
#   112,
#   57,
#   18330,
#   2103,
#   3638,
#   24,
#   492,
#   6273,
#   7548,
#   18331,
#   71,
#   3638,
#   910,
#   6273,
#   8680,
#   7548,
#   2345,
#   148,
#   192,
#   2319,
#   69,
#   5800,
#   10887,
#   34,
#   459,
#   2584,
#   495,
#   542,
#   292,
#   38,
#   899,
#   185,
#   2650,
#   2115,
#   30,
#   169,
#   50,
#   3,
#   16,
#   307,
#   347,
#   551,
#   1254],
#  [717,
#   4,
#   33,
#   703,
#   3028,
#   717,
#   182,
#   4,
#   33,
#   125,
#   8019,
#   228,
#   2238,
#   1169,
#   703,
#   422],
#  [2262,
#   206,
#   2283,
#   61,
#   180,
#   24,
#   1833,
#   4222,
#   603,
#   2702,
#   246,
#   799,
#   3665,
#   433,
#   3887,
#   974,
#   7846,
#   1,
#   814,
#   517],
#  [92,
#   3025,
#   174,
#   252,
#   3,
#   1636,
#   8097,
#   250,
#   11,
#   74,
#   15,
#   9659,
#   3,
#   520,
#   3286,
#   1572,
#   383,
#   57,
#   135,
#   208,
#   394,
#   968,
#   1049,
#   72,
#   226,
#   6283,
#   2764,
#   46,
#   174,
#   250,
#   72,
#   121,
#   117,
#   1999],
#  [146,
#   29,
#   1033,
#   5684,
#   140,
#   455,
#   1033,
#   5684,
#   905,
#   1013,
#   54,
#   3,
#   100,
#   43,
#   5356,
#   264,
#   146,
#   29,
#   564,
#   1,
#   1522,
#   137,
#   598,
#   939,
#   5,
#   9,
#   6838,
#   2849,
#   25,
#   868,
#   564,
#   16,
#   10,
#   5,
#   94,
#   16,
#   143,
#   214,
#   728,
#   331,
#   165,
#   159,
#   30,
#   1517,
#   79,
#   11,
#   285,
#   455,
#   776,
#   18,
#   825,
#   29,
#   191,
#   286,
#   2,
#   766,
#   146,
#   29,
#   1516,
#   140,
#   2092,
#   191,
#   94,
#   4,
#   2,
#   711,
#   396,
#   545,
#   696,
#   146,
#   29,
#   1,
#   1054,
#   1505,
#   18,
#   54,
#   78,
#   1809,
#   5,
#   136,
#   146,
#   29,
#   140,
#   1190,
#   60,
#   25,
#   1,
#   6,
#   6,
#   2468,
#   2859,
#   316,
#   380,
#   259,
#   205,
#   28],
#  [1025,
#   37,
#   1,
#   412,
#   16075,
#   471,
#   369,
#   3,
#   259,
#   6603,
#   6361,
#   345,
#   480,
#   648,
#   360,
#   10870,
#   1,
#   491,
#   8879,
#   14765,
#   152,
#   5916,
#   160,
#   1,
#   106,
#   238,
#   15173,
#   103,
#   1,
#   2788,
#   152,
#   312,
#   1173,
#   18332,
#   542,
#   309,
#   152,
#   95,
#   542,
#   145,
#   24,
#   413,
#   11428,
#   533,
#   25,
#   7,
#   180,
#   26,
#   152,
#   1479,
#   1967,
#   6,
#   106,
#   542,
#   8277,
#   1202],
#  [1299,
#   78,
#   1938,
#   12,
#   451,
#   319,
#   5370,
#   176,
#   102,
#   46,
#   449,
#   2034,
#   2156,
#   10344,
#   1853,
#   257,
#   1046,
#   454,
#   1599,
#   317,
#   164,
#   424,
#   190,
#   9095,
#   345,
#   904,
#   1747,
#   83,
#   2307,
#   5553,
#   1954,
#   65,
#   392,
#   68,
#   2302,
#   1587,
#   5917,
#   4272,
#   137,
#   102,
#   874,
#   2556,
#   3648,
#   1828,
#   1618,
#   69,
#   407,
#   937,
#   2089,
#   3382,
#   239,
#   164,
#   6,
#   5964,
#   661,
#   215,
#   12312,
#   10344,
#   434,
#   10344,
#   1152,
#   190],
#  [4, 1780, 126, 124, 181, 334, 393, 563, 591],
#  [146,
#   29,
#   140,
#   455,
#   905,
#   1013,
#   54,
#   3,
#   100,
#   43,
#   12050,
#   264,
#   146,
#   29,
#   1,
#   402,
#   4661,
#   221,
#   1089,
#   54,
#   289,
#   29,
#   680,
#   16,
#   29,
#   1764,
#   264,
#   1,
#   2750,
#   3214,
#   79,
#   1,
#   54,
#   680,
#   279,
#   79,
#   283,
#   479,
#   221,
#   1089,
#   54,
#   18,
#   54,
#   19,
#   11,
#   285,
#   455,
#   776,
#   18,
#   825,
#   29,
#   191,
#   286,
#   2,
#   766,
#   146,
#   29,
#   1516,
#   140,
#   2092,
#   191,
#   94,
#   16,
#   4,
#   2,
#   711,
#   396,
#   545,
#   696,
#   146,
#   29,
#   1,
#   1054,
#   1505,
#   18,
#   54,
#   78,
#   1809,
#   5,
#   136,
#   146,
#   29,
#   140,
#   1190,
#   60,
#   25,
#   1,
#   6,
#   6,
#   2468,
#   2859,
#   316,
#   380,
#   259,
#   4],
#  [1326, 1730, 792, 3405, 12, 74, 684, 2396, 354],
#  [1608, 148, 19, 319, 55, 166, 121, 294, 31, 24, 1166, 24, 1200],
#  [144,
#   396,
#   11,
#   58,
#   1365,
#   633,
#   95,
#   7492,
#   831,
#   3,
#   21,
#   722,
#   690,
#   30,
#   1023,
#   174,
#   252,
#   120,
#   11,
#   2042,
#   45,
#   711,
#   396,
#   671,
#   1064,
#   121,
#   478,
#   7346],
#  [993, 8978, 205, 77, 319, 2686, 15174, 10345, 11825, 8278, 1868, 270, 1409],
#  [20, 39, 1206, 44, 5259, 84, 250],
#  [145,
#   384,
#   671,
#   2420,
#   1387,
#   25,
#   11065,
#   3009,
#   600,
#   2947,
#   695,
#   551,
#   1101,
#   9,
#   3508,
#   190,
#   2627,
#   91,
#   548,
#   500,
#   5230,
#   16598,
#   10528,
#   440,
#   8189],
#  [71,
#   2313,
#   2,
#   193,
#   114,
#   873,
#   24,
#   46,
#   412,
#   873,
#   222,
#   1067,
#   4132,
#   51,
#   10336,
#   135,
#   3161,
#   15175,
#   4,
#   2,
#   222,
#   18332,
#   1734,
#   2518,
#   1241,
#   838,
#   3606,
#   3061,
#   51,
#   2,
#   69,
#   340,
#   436,
#   6,
#   1031,
#   351,
#   2127,
#   2366,
#   1995,
#   8880,
#   2560,
#   259,
#   36,
#   85,
#   95,
#   1734,
#   1017,
#   10,
#   275,
#   380,
#   308,
#   2477,
#   5954,
#   667,
#   7150,
#   14,
#   5658,
#   135,
#   44,
#   7414,
#   2527,
#   136,
#   182,
#   879,
#   314,
#   151,
#   98,
#   311,
#   100,
#   111,
#   413,
#   149,
#   48,
#   106,
#   103,
#   74,
#   5918,
#   54,
#   168],
#  [904,
#   1168,
#   1284,
#   3199,
#   2566,
#   171,
#   2388,
#   3515,
#   1083,
#   9916,
#   2388,
#   652,
#   201,
#   7,
#   201,
#   171,
#   2388,
#   6133,
#   31,
#   204,
#   156,
#   354,
#   493,
#   60,
#   691,
#   857,
#   3259,
#   2566],
#  [11066,
#   6,
#   2126,
#   77,
#   289,
#   178,
#   337,
#   480,
#   118,
#   39,
#   2,
#   469,
#   164,
#   114,
#   106,
#   3231,
#   14,
#   3],
#  [2027,
#   10068,
#   1291,
#   11429,
#   468,
#   9,
#   65,
#   85,
#   210,
#   90,
#   201,
#   160,
#   1050,
#   2062,
#   13,
#   1861,
#   4707,
#   5329,
#   188,
#   13093,
#   156,
#   5579,
#   2687,
#   1143,
#   659,
#   803,
#   932,
#   5579,
#   2687,
#   1405,
#   200,
#   463,
#   1480,
#   6549,
#   71,
#   242,
#   239,
#   1477,
#   909,
#   92,
#   11622,
#   137,
#   1441,
#   2038,
#   1978,
#   1369,
#   9660,
#   178,
#   180,
#   224],
#  [62,
#   12840,
#   129,
#   342,
#   1637,
#   706,
#   2533,
#   203,
#   706,
#   43,
#   325,
#   12585,
#   93,
#   691,
#   369,
#   43,
#   376],
#  [7089, 13386, 10529, 162, 1301, 2553, 5801],
#  [1049, 70, 472, 181, 2969, 172, 409, 777],
#  [577, 4002, 104, 379, 1756, 717, 3678, 4273, 357, 24, 405, 880, 304],
#  [5, 136, 79, 33, 78, 526, 15, 169, 76, 37, 1714, 893],
#  [54,
#   332,
#   2002,
#   612,
#   5448,
#   293,
#   1,
#   92,
#   426,
#   5802,
#   4173,
#   11,
#   332,
#   2002,
#   612,
#   267,
#   16599,
#   51,
#   8681,
#   4,
#   2,
#   612,
#   21,
#   445,
#   612],
#  [19073, 358, 19073, 300, 19073, 1167, 68, 1086, 1231, 4821, 215, 1451, 322],
#  [60,
#   5115,
#   71,
#   46,
#   849,
#   688,
#   4115,
#   69,
#   305,
#   2062,
#   222,
#   2638,
#   314,
#   4115,
#   12051,
#   4115,
#   1425,
#   4115,
#   1896,
#   46,
#   753,
#   4663,
#   2996,
#   77,
#   761,
#   226,
#   835,
#   673,
#   113,
#   879,
#   3496,
#   11826,
#   18333,
#   1046,
#   454,
#   1090,
#   4115,
#   1824,
#   309,
#   2638,
#   314,
#   4115,
#   77,
#   3004,
#   104,
#   149,
#   30,
#   295,
#   2205,
#   3325,
#   980,
#   1896,
#   149,
#   2336,
#   295,
#   4115,
#   6419,
#   105,
#   2378,
#   69,
#   3854,
#   3325,
#   980,
#   1896,
#   129,
#   209,
#   4236,
#   1858,
#   7346,
#   3496,
#   2665,
#   1012,
#   293],
#  [4699,
#   126,
#   108,
#   67,
#   5919,
#   794,
#   2288,
#   282,
#   451,
#   50,
#   5919,
#   98,
#   2704,
#   2288,
#   124,
#   1005,
#   3959,
#   114,
#   18,
#   88,
#   79,
#   66,
#   195,
#   152,
#   111,
#   240,
#   51,
#   680,
#   2927,
#   181,
#   1312,
#   1061,
#   560,
#   117,
#   316,
#   16600,
#   1312,
#   18,
#   17,
#   157,
#   16600,
#   198,
#   1490,
#   340,
#   502],
#  [197,
#   3328,
#   2593,
#   393,
#   2833,
#   197,
#   586,
#   320,
#   1373,
#   2,
#   17116,
#   7868,
#   2970,
#   2036,
#   1281,
#   14766,
#   4290,
#   1200,
#   2593,
#   7213,
#   2,
#   109,
#   358,
#   1668,
#   2967,
#   9,
#   6192,
#   1179,
#   25,
#   7868,
#   26,
#   350,
#   56,
#   1554,
#   1064,
#   2042],
#  [207,
#   8,
#   1025,
#   10,
#   418,
#   415,
#   24,
#   2112,
#   355,
#   341,
#   12052,
#   8098,
#   9284,
#   692,
#   1,
#   57,
#   376,
#   22,
#   691,
#   10859,
#   120,
#   15,
#   1025],
#  [642,
#   3550,
#   1,
#   4434,
#   54,
#   7,
#   29,
#   51,
#   1848,
#   1120,
#   28,
#   125,
#   1287,
#   1,
#   708,
#   238,
#   3671,
#   19,
#   37,
#   4,
#   2,
#   1198,
#   70,
#   40,
#   29,
#   51,
#   23,
#   807],
#  [7290, 12586, 10206],
#  [201,
#   74,
#   431,
#   2592,
#   1433,
#   1433,
#   1433,
#   1433,
#   1433,
#   98,
#   1488,
#   5448,
#   442,
#   2736,
#   864,
#   1773,
#   155,
#   757,
#   1838,
#   16601,
#   8872,
#   15625],
#  [371,
#   177,
#   476,
#   791,
#   12313,
#   1311,
#   26,
#   127,
#   1438,
#   25,
#   19860,
#   12313,
#   1194,
#   791,
#   6,
#   171,
#   12,
#   8773,
#   456,
#   791,
#   8774,
#   957,
#   7648,
#   3005,
#   529,
#   533,
#   25,
#   40,
#   78,
#   4698,
#   8084],
#  [6193,
#   15176,
#   205,
#   9661,
#   4082,
#   365,
#   8,
#   158,
#   19,
#   8,
#   19,
#   353,
#   158,
#   215,
#   5835,
#   8456,
#   551,
#   12841,
#   1746,
#   68,
#   3761,
#   829,
#   1196,
#   909,
#   2983,
#   1223,
#   12053,
#   10719,
#   186,
#   3074,
#   1746,
#   10732,
#   1769,
#   7347,
#   5449,
#   829,
#   12053,
#   9662,
#   8456,
#   829,
#   829,
#   2388,
#   1606,
#   1418,
#   889,
#   1117,
#   5449,
#   2314,
#   9796,
#   205,
#   206,
#   7347,
#   1196,
#   8456,
#   40,
#   24,
#   1273,
#   3761,
#   9194,
#   3586,
#   24,
#   1196,
#   2482,
#   3688,
#   92,
#   2482,
#   7493,
#   3591,
#   1196,
#   5449],
#  [320, 859, 237, 1689, 4031, 878, 9, 85, 4],
#  [3325, 1033, 2, 277, 111, 6, 8, 1057, 17, 452, 45],
#  [153,
#   9797,
#   7783,
#   8007,
#   38,
#   1219,
#   4388,
#   13094,
#   4388,
#   13094,
#   4032,
#   16602,
#   7422,
#   829,
#   583,
#   501,
#   5066,
#   5231,
#   901,
#   485,
#   1193,
#   2944,
#   43,
#   3901,
#   1714,
#   565,
#   276,
#   94,
#   10888,
#   2576,
#   376,
#   50,
#   2010,
#   5764,
#   1102,
#   440,
#   109,
#   1403,
#   922,
#   1834,
#   21,
#   175,
#   216,
#   293,
#   1215,
#   2010,
#   126,
#   1215,
#   2010,
#   2681,
#   4932,
#   544,
#   11827,
#   1359,
#   124,
#   2010,
#   1958,
#   35,
#   1030,
#   898,
#   866,
#   102,
#   88,
#   1087,
#   5,
#   60,
#   70,
#   1087,
#   19861,
#   6467,
#   43,
#   20],
#  [7494,
#   4859,
#   221,
#   5582,
#   709,
#   1051,
#   1519,
#   741,
#   4871,
#   3795,
#   639,
#   6240,
#   236,
#   12054,
#   10,
#   2755,
#   3481,
#   1721,
#   2307,
#   986,
#   6043,
#   12314,
#   14046,
#   2355,
#   8020,
#   16603,
#   1161,
#   51,
#   7,
#   5293,
#   2812,
#   236,
#   8661,
#   17117,
#   2604,
#   308,
#   7090,
#   333,
#   2511,
#   11067,
#   401,
#   8661,
#   17117,
#   2604,
#   1024,
#   3417,
#   3036,
#   5765],
#  [166,
#   58,
#   2992,
#   1,
#   134,
#   6,
#   24,
#   166,
#   364,
#   59,
#   51,
#   2,
#   1461,
#   792,
#   1519,
#   40,
#   10,
#   295,
#   286,
#   596,
#   11,
#   1,
#   26,
#   249,
#   262,
#   2543,
#   26,
#   16,
#   1567,
#   304,
#   2429,
#   661,
#   1261,
#   206,
#   98,
#   712,
#   394,
#   3914,
#   42,
#   4362,
#   106,
#   1033,
#   2022,
#   1926,
#   858,
#   104,
#   198,
#   4363],
#  [804, 1369, 509, 533, 656, 4830, 1104, 202, 45, 4],
#  [2984,
#   72,
#   523,
#   166,
#   72,
#   586,
#   12,
#   9532,
#   481,
#   49,
#   482,
#   6185,
#   134,
#   49,
#   644,
#   444,
#   6839,
#   4325,
#   7,
#   155,
#   13,
#   801,
#   1722,
#   113,
#   2931,
#   57,
#   444,
#   908,
#   113,
#   49,
#   2931,
#   2984,
#   36,
#   872,
#   406,
#   7,
#   2061,
#   975,
#   2642,
#   171,
#   201,
#   327],
#  [172,
#   550,
#   577,
#   129,
#   172,
#   105,
#   55,
#   270,
#   130,
#   52,
#   7495,
#   4491,
#   206,
#   205,
#   884,
#   552],
#  [12041,
#   2513,
#   752,
#   648,
#   4635,
#   18,
#   3529,
#   5762,
#   549,
#   103,
#   2191,
#   12041,
#   2513,
#   7019,
#   752,
#   929,
#   4616,
#   10201,
#   2474,
#   166,
#   752,
#   456,
#   4452,
#   718,
#   1238,
#   3310,
#   3457,
#   1021,
#   2608,
#   4598,
#   7782,
#   14,
#   17118,
#   752,
#   1871,
#   5554,
#   752,
#   8881,
#   752,
#   49,
#   344,
#   3457,
#   6,
#   242,
#   149,
#   2614,
#   2608,
#   2331,
#   2608,
#   604,
#   718,
#   208,
#   12,
#   5371,
#   4384,
#   2513,
#   2692,
#   2389,
#   824,
#   3732,
#   12,
#   5371,
#   7214,
#   565,
#   98,
#   1958,
#   2608,
#   86,
#   49,
#   5200,
#   14400,
#   12041,
#   1919,
#   19,
#   252],
#  [10889, 4232, 38, 5, 344, 10889, 268, 4232],
#  [5, 519, 33, 15, 169, 76, 37, 674],
#  [704,
#   729,
#   489,
#   87,
#   2115,
#   11623,
#   8099,
#   7347,
#   7085,
#   258,
#   185,
#   2115,
#   185,
#   31,
#   428,
#   934,
#   69,
#   19862,
#   11828,
#   176,
#   13387,
#   1090,
#   7347,
#   459,
#   1551,
#   465,
#   396,
#   7348,
#   2920,
#   465,
#   789,
#   295,
#   613,
#   3241,
#   349,
#   934,
#   702,
#   11828,
#   176,
#   13387,
#   236,
#   7291,
#   5998,
#   233,
#   842,
#   1476,
#   7347,
#   5693,
#   258,
#   13388,
#   1695,
#   228,
#   1551,
#   465,
#   1332,
#   69,
#   297,
#   3,
#   692,
#   7347,
#   1010,
#   4209,
#   19863,
#   11624,
#   3292,
#   78,
#   14031,
#   3204,
#   4488,
#   176,
#   11828,
#   1567,
#   203,
#   2934,
#   2314,
#   4288,
#   7020,
#   258,
#   3292,
#   143,
#   3079,
#   69,
#   79,
#   1023,
#   143,
#   1130,
#   16604,
#   369,
#   2934],
#  [435, 20, 435, 231, 1138, 1138, 456, 134, 3917, 2375, 435, 27],
#  [7561, 1930, 9633, 58, 1618, 3193, 8564, 1],
#  [250,
#   6680,
#   51,
#   2676,
#   14047,
#   4687,
#   90,
#   2471,
#   14767,
#   1,
#   241,
#   17119,
#   2648,
#   2329,
#   4380,
#   653,
#   3381,
#   515,
#   2782,
#   1870,
#   893,
#   3529,
#   4119,
#   10733,
#   5836,
#   153,
#   233,
#   550,
#   2110,
#   13,
#   923,
#   2967,
#   3726,
#   23,
#   2447,
#   520,
#   2657,
#   23,
#   309,
#   6,
#   171,
#   1766,
#   1870,
#   15626,
#   114,
#   17119,
#   2648,
#   71,
#   4955,
#   5232,
#   198,
#   573,
#   97,
#   1],
#  [14048, 1281, 97, 2456, 97],
#  [2160,
#   8370,
#   18,
#   240,
#   10530,
#   1008,
#   1403,
#   6139,
#   71,
#   7869,
#   177,
#   760,
#   4830,
#   600,
#   2733,
#   6,
#   6140,
#   3914,
#   512,
#   10530,
#   153],
#  [27, 707, 418, 1513, 59, 11, 7725, 6370, 210, 35, 4308, 1601],
#  [5042, 338, 338, 19074, 2286],
#  [53, 91, 8571, 131, 1],
#  [81,
#   93,
#   3,
#   125,
#   8,
#   97,
#   96,
#   28,
#   437,
#   269,
#   6776,
#   18,
#   28,
#   62,
#   494,
#   768,
#   3,
#   3720,
#   6569,
#   41,
#   36,
#   281,
#   35,
#   16,
#   186,
#   1550,
#   2390,
#   36,
#   2166,
#   33,
#   1623,
#   701,
#   352,
#   41,
#   36,
#   61,
#   8682,
#   4307,
#   1326,
#   105,
#   52,
#   364,
#   186,
#   1800,
#   2974,
#   3,
#   395,
#   150,
#   163,
#   1829,
#   301,
#   150,
#   267,
#   65,
#   36,
#   812,
#   122,
#   1627,
#   1326,
#   1488,
#   1623,
#   368,
#   2170,
#   150,
#   113,
#   128,
#   222,
#   39,
#   4,
#   2,
#   97,
#   1244,
#   4,
#   2,
#   66,
#   36,
#   1467,
#   1907,
#   1179,
#   2508,
#   5283,
#   1149,
#   2119,
#   2508,
#   36,
#   22,
#   204,
#   7496,
#   28,
#   686,
#   204,
#   35,
#   80,
#   2231,
#   452,
#   17684,
#   363,
#   32,
#   108,
#   314,
#   657,
#   17,
#   359,
#   60,
#   10890,
#   494,
#   22,
#   10890,
#   18,
#   28,
#   60,
#   35,
#   39,
#   19864,
#   239,
#   11,
#   2,
#   63,
#   54,
#   5,
#   75,
#   1919,
#   29,
#   2,
#   10,
#   1919,
#   9173,
#   2,
#   28,
#   7726,
#   73,
#   11,
#   54,
#   72,
#   65,
#   853,
#   1258,
#   6,
#   8,
#   22,
#   106,
#   4353,
#   3,
#   2231,
#   3041,
#   5555,
#   353,
#   269,
#   7,
#   186,
#   18334,
#   972,
#   8,
#   975,
#   36,
#   37,
#   2231,
#   72,
#   4453,
#   28,
#   52,
#   73,
#   167,
#   1256,
#   2,
#   2120,
#   8021,
#   186,
#   560,
#   2216,
#   231,
#   368,
#   2170,
#   327,
#   15627,
#   4,
#   346,
#   1198,
#   850,
#   231],
#  [414,
#   512,
#   610,
#   18335,
#   3293,
#   1189,
#   115,
#   434,
#   6419,
#   18336,
#   4324,
#   69,
#   846,
#   992,
#   2739,
#   14049,
#   2727,
#   103,
#   764,
#   1738,
#   8,
#   7649,
#   2826,
#   2826,
#   3470,
#   2826,
#   320,
#   85,
#   7151,
#   3481,
#   289,
#   154],
#  [779,
#   851,
#   423,
#   87,
#   1589,
#   1744,
#   1,
#   206,
#   48,
#   153,
#   390,
#   1,
#   229,
#   1,
#   390,
#   300,
#   3919,
#   44,
#   12,
#   74,
#   794,
#   79,
#   213,
#   19,
#   98,
#   877,
#   1,
#   936,
#   70,
#   10734,
#   1278,
#   7,
#   263,
#   90,
#   794,
#   2694,
#   3803,
#   13389,
#   326,
#   300,
#   237,
#   376,
#   53,
#   1715,
#   19,
#   5406,
#   1,
#   23,
#   309,
#   79],
#  [142,
#   13707,
#   5606,
#   6612,
#   920,
#   1191,
#   19865,
#   6271,
#   6734,
#   710,
#   472,
#   19,
#   8088,
#   710,
#   6,
#   9,
#   117,
#   3835,
#   1761,
#   549,
#   1099,
#   212,
#   3831,
#   3992,
#   526,
#   19866,
#   2118,
#   218,
#   1795,
#   19,
#   6,
#   9003,
#   896,
#   1264,
#   316,
#   508,
#   95,
#   57,
#   2374,
#   133,
#   190,
#   832,
#   3918,
#   280,
#   17,
#   21,
#   50,
#   17120,
#   3,
#   97,
#   15,
#   1206,
#   1111,
#   1636,
#   512,
#   728,
#   318,
#   69,
#   3835,
#   90,
#   39,
#   15,
#   373,
#   18337,
#   13,
#   642,
#   11,
#   15,
#   814,
#   2173,
#   106,
#   1766],
#  [281, 335, 19867, 132, 1014, 47, 116, 1301],
#  ...]

# %%
# Check the distribution of sentence lengths to determine length of input
num_words = []
for entry in train_tokenized_x:
    num_words.append(len(entry))
fig, ax = plt.subplots()
sns.distplot(num_words, hist = True, kde = False)
ax.set_xlim(0,300)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Pad input so that they are all of the same length
MAX_WORD = 150
padded_train_x = pad_sequences(train_tokenized_x, maxlen = MAX_WORD)
padded_test_x = pad_sequences(test_tokenized_x, maxlen = MAX_WORD)
padded_train_x
# Out:
# array([[    0,     0,     0, ...,    57,    12,  3256],
#        [    0,     0,     0, ...,   697,  7265,    87],
#        [    0,     0,     0, ...,  2166,   567,   348],
#        ...,
#        [    0,     0,     0, ...,  3302, 13213,  4294],
#        [    0,     0,     0, ...,   263,    54,    61],
#        [    0,     0,     0, ...,   238,  1411,  1589]], dtype=int32)

# %%
import gensim

# Use gensim to load GoogleNews pre-trained word embeddings
INPUT_FILE = "GoogleNews-vectors-negative300.bin.gz"
word2vec = gensim.models.KeyedVectors.load_word2vec_format(INPUT_FILE, binary=True)

# %%
# Convert gensim object into a python dictionary
dict_size = len(tokenizer.word_index)
embedding_index = {}
for word in word2vec.wv.vocab:
    embedding_index[word] = word2vec.word_vec(word)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   after removing the cwd from sys.path.

# %%
# Check to see if there is any common word that will not be factored into model because of issues with embeddings
set_word = set()
for row in train_cleaned_x:
    for word in row:
        set_word.add(word)
not_in = []
for word in set_word:
    if word not in embedding_index:
        not_in.append(word)
not_in
# Out:
# ['wwwcircumcisionorg',
#  'sangharaj',
#  'cureently',
#  'wisconsinwhitewater',
#  'canyouhearmenow',
#  'fyromnor',
#  'propaedo',
#  '11851200',
#  'introit',
#  'tubman',
#  'springloaded',
#  'halliburtons',
#  '1753',
#  'beatriz',
#  'islandsyes',
#  'majorinos',
#  'redwolf24',
#  'elss',
#  'vol29',
#  'gtalondon',
#  'eytmology',
#  '18441900',
#  'euphrates',
#  'harnack',
#  'qho',
#  'amandajm',
#  'nlcategoriejiddisch',
#  'hujsmodi',
#  'initate',
#  'telu',
#  'wpaspersions',
#  'filepachygrapsus',
#  'southerneuropean',
#  'stringerone',
#  'regared',
#  'editirial',
#  'anglocentric',
#  'tthus',
#  'nadujpeg',
#  'propagabda',
#  'maupassant',
#  'autrey',
#  'webforums',
#  'prelinguistic',
#  'numberspaceunit',
#  'webccsuedu',
#  'wongfu',
#  'perfroming',
#  'otgrtype',
#  'programit',
#  '2show',
#  'atach',
#  'laudahnredirect',
#  'loger',
#  'esb',
#  'mosar',
#  'vendetta87the',
#  '24p',
#  'openandshut',
#  'amercias',
#  'wwwworkingforchangecom',
#  '3777752spn',
#  'it17317422248',
#  'moneywhoopssorry',
#  'ensurance',
#  '8tops',
#  'krw',
#  'greetings2486116250',
#  'wpcivility',
#  'tripodics',
#  'tempremental',
#  'kwandu1',
#  'exerienced',
#  'wpbiofor',
#  'crosslane',
#  '15978jpg',
#  'nguyen19051981',
#  'wazzzzzzzzzz',
#  '24177120138',
#  'misleadingis',
#  'fathappy',
#  'statutu',
#  'goerlitz',
#  'antonios',
#  'irvto',
#  'virionenpng',
#  'administratr',
#  'unversioned',
#  'cashman',
#  'preassumed',
#  'japaneese',
#  'howells',
#  'psychologyical',
#  'blanda',
#  'fint',
#  'naharkanta',
#  'antartica',
#  'szlasi',
#  'misterwikis',
#  'blackngold9s',
#  'straighthaired',
#  'mould',
#  'wageror',
#  'bearingswho',
#  'miseyou',
#  'pratiher',
#  'delluebi',
#  '536250229',
#  'imperceptive',
#  '5915424147',
#  'bahaim',
#  'lotle',
#  'diseman',
#  'sineb',
#  'gandhinagar',
#  'povenm',
#  'cullens',
#  'sentencedo',
#  'shadomx',
#  'durationfor',
#  'sxn',
#  'aurine',
#  'walrusses',
#  'dcmcdevits',
#  'hartigan',
#  'infoboxberbers',
#  'berlusconi',
#  'brandand',
#  '50pb',
#  'karadjordjes',
#  '827144151',
#  '991652261',
#  'bolcked',
#  'recte',
#  'crzrussians',
#  'josebautista',
#  'bicols',
#  'anchoragenet',
#  'brlplatinum',
#  'ashokavadana',
#  'alonethe',
#  'allindiano',
#  'ahhrelief',
#  '1010000',
#  '762028156',
#  'gorbachov',
#  'ohigginses',
#  'shaban',
#  'paxcoder',
#  'butwal',
#  'ashdown',
#  'moret',
#  'defra',
#  'taihu',
#  'leongkw',
#  'sexit',
#  'gottglubig',
#  'garrait',
#  'speeddeleting',
#  'bstard',
#  'id158332',
#  'otsep',
#  'userchristianity922s',
#  'trimspa',
#  'grrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrr',
#  'uzbekistani',
#  'portmapping',
#  'abovenamed',
#  'freuds',
#  'caribbeanbefore',
#  'fuckity',
#  'selecciones',
#  'lula',
#  '1245ishand',
#  'dickmania',
#  'pregermanic',
#  'bradenton',
#  'pandianillegoconcamion1187776',
#  'pantocrator',
#  'icfbigov',
#  'userxuanwu',
#  'promsulim',
#  'moryk',
#  'socialphobia',
#  'version2s',
#  'mvah',
#  'sourceso',
#  '26puccihtml',
#  'friedmanite',
#  'borification',
#  'doubleissue',
#  'macrodata',
#  'dalects',
#  'cma009a',
#  'mentinoedare',
#  '78108108254',
#  'tonyukuk5jpg',
#  'scalzis',
#  'rosens',
#  'hebrer',
#  'bavebter',
#  'sixlane',
#  'murt',
#  'easana',
#  'cdt4w',
#  'verdammet',
#  'inablility',
#  'sabaw',
#  'ambrogio',
#  'smithee',
#  'talkredbird',
#  'europeoid',
#  '200601196013html',
#  'stubborncomments',
#  'waterthis',
#  '691582897',
#  'badutab',
#  'greenmaven',
#  'bdds',
#  '2001',
#  'wpdnftt',
#  'pbskids',
#  'refnational',
#  'formaly',
#  'wparbpia',
#  'sithush',
#  'nasalized',
#  'q22operation',
#  'twelvers',
#  'userthewolfchild',
#  'pleiades',
#  'madalyn',
#  'prtvdarvha',
#  'reallya',
#  'usermynameisthemasterofallofthefives',
#  'saakashvilis',
#  'citylaugh',
#  'kapur',
#  'messhermit',
#  'discrtion',
#  'misprisions',
#  'userkualilance',
#  'alonzo',
#  'wtexternal',
#  'peakes',
#  'finishead',
#  'kryzstof',
#  'wcm',
#  '91kb',
#  'karaiskakis',
#  'forcefeeding',
#  'brokenquality',
#  'berkut',
#  'recordar',
#  'whitelaw',
#  'capitalfm',
#  'diouf',
#  '0524',
#  'brightline',
#  'imagefacialjpg',
#  'guerrafacundo',
#  'cientificos',
#  'undertrialryryr',
#  'thomas16151112',
#  'kennedyedge',
#  'academypng',
#  'epagum',
#  'asdf123asdf',
#  'ilr',
#  'stalkertype',
#  'nonmsk',
#  'share30',
#  'warofdreams',
#  '16h',
#  'sendinh',
#  'assmy',
#  'twentyfirst',
#  'erlade',
#  'wwwmotogpcom',
#  'esperanzans',
#  'ouldnt',
#  'citeability',
#  'heonsi',
#  'medialicensing',
#  'demiurges',
#  'jihadistfundamentalist',
#  'keyo',
#  'ingorant',
#  'bozhinov',
#  'inresponse',
#  'nsaum75',
#  'arunning',
#  'marx0728',
#  'deiz',
#  'committef',
#  'noncontentious',
#  'priceshtm',
#  'oshwah',
#  'greeneyed',
#  'patawmekes',
#  '221471852',
#  'patrice',
#  'tayaks',
#  'khwarazmian',
#  'wlak',
#  'osam',
#  'coraline',
#  'banneduser032906scomm3rapng',
#  'languagetc',
#  'bullshits',
#  'yanow',
#  'thehuddle',
#  '86149148121',
#  'validifies',
#  'orthodoxoriented',
#  'lolonly',
#  'konzerthaus',
#  'userc',
#  'edip',
#  'saaaaad',
#  'repeted',
#  '12v',
#  'talkphilippines',
#  'cunt76100195188',
#  '241573202',
#  'mexicali',
#  'ukrussianemtsovukraineidukkbn0m120620150305',
#  'polack',
#  'wikipediainfo',
#  'californias',
#  'smallerscope',
#  'wwwip2locationcom',
#  'bangn',
#  'roxieandmartha',
#  'redistributabilty',
#  'religionneutral',
#  'userbrangifer',
#  '5300011622',
#  'ffd',
#  'genosides',
#  'euridice',
#  '9410157134',
#  'romdied',
#  'tralle',
#  '20100212',
#  'msnbccom',
#  'userworm',
#  'wikihistorians',
#  'wikipedadia',
#  't90ams',
#  'runoftheriver',
#  'workvariety',
#  '49',
#  'valis',
#  '548172114oldid',
#  'selfnom',
#  'iia',
#  'masadans',
#  'dasu',
#  'p4k',
#  'tt0122541',
#  'heikki',
#  'issue5jpg',
#  'yestreb',
#  'commentremoval',
#  'therealfennshysas',
#  'aboiut',
#  '0614',
#  'farh',
#  'indexphptitlesinofrench',
#  '2021414050',
#  'difcovering',
#  'anisha',
#  'ramm',
#  'p311',
#  'opbjects',
#  'termpage',
#  'nonalbum',
#  'vf84',
#  'arrangementsending',
#  'valignmiddle',
#  '78chromosome',
#  'brontes',
#  'matthewfenton',
#  '60ies',
#  'eladia',
#  'plagerizing',
#  'davidweill',
#  'seagraves',
#  '331',
#  'bachuk',
#  'novinite',
#  'talk198236024',
#  '5088',
#  'tencomau',
#  'gunscam',
#  'systematiacally',
#  'bakersvilles',
#  'mvt',
#  'sparxxx',
#  'bidisha',
#  'nowitzki',
#  'eastvanhalen',
#  '3978222zoom',
#  'rotherham',
#  '25197',
#  'total27',
#  'mygalomorphae',
#  'burmanos',
#  'samler',
#  'sukhpal',
#  'photouploaded',
#  '893',
#  '122109127168',
#  'warnigns',
#  'borrowvery',
#  'wwwsweetwatercom',
#  'e91',
#  'moyers',
#  '08111999',
#  'noncatholic',
#  'freep',
#  'inhabitted',
#  'web610x924jpg',
#  'monotropa',
#  'kroll',
#  'wikipediaweeklycom',
#  'banthank',
#  'kuching',
#  'stevebarker',
#  'slakr',
#  '1431',
#  'industryoriented',
#  'demowikinewsorg',
#  '1922',
#  '187312465',
#  'omapere',
#  'warefar',
#  'nowlost',
#  'wwwcrunchyrollcom',
#  'rfk',
#  'finneganw',
#  'mazzali',
#  'qadris',
#  'popochan',
#  'villegas',
#  'wayseven',
#  'hankypanky',
#  'thereso',
#  'resolutionit',
#  'lacntabyoung',
#  'wellcome',
#  'talkfnlaysonmy',
#  'nickalls',
#  'girlfriendtwicein',
#  'moldova',
#  'setjeam',
#  '7131',
#  'reestabslishment',
#  'thorun',
#  'twistes',
#  'lookign',
#  'christiani',
#  'countrypoor',
#  'kerdar',
#  'usermanav',
#  'wwwthornemoormaraudersikcom',
#  '1line',
#  'xronia',
#  'rexs',
#  'bandwagonplenty',
#  'newenergytimescom',
#  'gneus',
#  'assistead',
#  'muchfurthermore',
#  'awwwwwwww',
#  'eou',
#  'wpiowa',
#  'technicas',
#  'cusssssssse',
#  'murghab',
#  'stillstandings',
#  'scrible',
#  '1463e280931878',
#  'dorae',
#  'zacharia',
#  'eyban',
#  'don27t',
#  'discussioncorrect',
#  'austar',
#  'sarr',
#  'schosha',
#  'laertes',
#  'helpoverview',
#  'hamsterdunce',
#  'nomdate',
#  'frienss',
#  'feilding',
#  'inlcluding',
#  'aubusinessinsidercom',
#  '23th',
#  '76168175233',
#  'illwilled',
#  'excellenttopcom',
#  'ranmafag',
#  'saintcyr',
#  '212174383',
#  'valuejet',
#  'guysmost',
#  'pleesed',
#  'waiste',
#  '2602252d2d4170dea9f7b27524c92',
#  'evanh',
#  'repacing',
#  'tarvupedia',
#  'cmh',
#  'baggs',
#  'demedi',
#  'einaudi',
#  'himthanks',
#  'sacha',
#  'introuction',
#  'wwwwarbirdregistryorg',
#  'talkfinal',
#  'ainaalfddarladarlingdearlylovedeternalgirlforevergirlforevermydarlingicongirlkyra',
#  '129782207',
#  'anticipiated',
#  'ceated',
#  'franconiaspringfield',
#  'queerrights',
#  'nieper',
#  'weekendthree',
#  'wikipolice',
#  'canadianborn',
#  'einsteinbud',
#  'enfermeras',
#  'ingediants',
#  '5tabnicco',
#  'f4e',
#  'tsargush',
#  'wellmaintained',
#  'pronuons',
#  '25mph',
#  'verein',
#  'thebig',
#  'wwwhimivestcom',
#  'talkcomparison',
#  'timy',
#  'smps',
#  'rd1team15',
#  'piecebypiece',
#  '5052',
#  'kaikolans',
#  'usermikemcgd',
#  'sinkala',
#  'ingorance',
#  'ghirlaphobes',
#  'apreciated',
#  'uberlameness',
#  'divisionrelated',
#  '179pxaldrin',
#  'iraqna',
#  'questiona',
#  'wwwskepticfilesorg',
#  'interestby',
#  '86140193228',
#  'fkennedys',
#  '178263946',
#  'it941682108',
#  'pp1lpg',
#  'jolys',
#  'jultomten',
#  'bloh',
#  'invers',
#  'pcl20125',
#  'mangojuices',
#  'softballing',
#  'coimbatore',
#  'cnamethe',
#  'drugsellers',
#  'barrak',
#  '000hz',
#  'tangra',
#  'pashtun',
#  'talk194144111210',
#  '24210144230',
#  'farfetchd',
#  'wehatever',
#  'mspeciallinksearch',
#  'encouragemets',
#  'hdt1215',
#  'aspergersor',
#  'grafakos',
#  'historyphpindexentries',
#  'talkscouting',
#  'btb',
#  'zootopia',
#  'imdaking',
#  'attentionthis',
#  'arrise',
#  'talkembassy',
#  'newlyformed',
#  'caoabilites',
#  '8412780114',
#  'useranonimu',
#  'medawatchchiya',
#  'andrica',
#  'katelyn',
#  'kingsport',
#  'harlows',
#  'stoller',
#  'bavariafilmplatz',
#  'accou8ntable',
#  'jacot',
#  'exspecial',
#  'unreliabe',
#  'sub1',
#  '0cc8q6aewatgo',
#  'versoin',
#  'austrasia',
#  'sitethis',
#  '14th15th',
#  'visitcur',
#  'telangan',
#  'wwwkentnet',
#  'gamesradar',
#  'japanophile',
#  'mpep',
#  'rsi',
#  'fddddddddddddddddddddddddd',
#  'wikipediauploading',
#  'sothe',
#  'peoperly',
#  'b29s',
#  'kiddyporn',
#  'distinctnessnot',
#  'alsayf',
#  'panti',
#  'vukcevic',
#  'baumann',
#  '1975101102',
#  'bhow',
#  'us250',
#  'hilberg',
#  'kullanc',
#  'anthroplogy',
#  'editsif',
#  'irishlanguage',
#  'dereks',
#  'aimak',
#  'm16',
#  'bhutia',
#  'calliphoridae',
#  'arachnoidcystnet',
#  'talkgrandwizard',
#  '8223149238',
#  'novaliches',
#  'histrocial',
#  'nonkorean',
#  'shigurui10',
#  'again205189194250',
#  'massachusettss',
#  'threatheing',
#  'imagelewisbio1jpg',
#  'eurofightercom',
#  'mumbletymumble',
#  'kotorom',
#  'quanify',
#  'glad78',
#  'ridiculious',
#  'selfaggrandizing',
#  'dynamization',
#  'whitestone',
#  'mahasen',
#  'jahre',
#  'adiant',
#  'encyclopediafriendly',
#  'wddm',
#  'exrta',
#  'wikipedialist',
#  'szeyuan',
#  'lfasz',
#  'misunderatanding',
#  'verdana',
#  'doublevoting',
#  'repulican',
#  'peraa',
#  'dnipro',
#  'camarillo',
#  'fastifex',
#  'argonian',
#  'wwwthemillerscouk',
#  'videocardzcom',
#  'strawmans',
#  'commonname',
#  'no540',
#  'substcopyvio',
#  'yorkshireman',
#  'wikietiquette',
#  'kearny',
#  'oncelive',
#  'talkindependence',
#  'faecc8',
#  'assberger',
#  'ems2',
#  'appearencesthat',
#  'talkgourami',
#  'mmys',
#  'beda',
#  'cityroomblogsnytimescom',
#  'prostitude',
#  'mehttps',
#  'rabdasi',
#  '26eee',
#  'ryancross',
#  'melanien',
#  'racistyou',
#  'talkmike',
#  'dominicanyou',
#  'sponcors',
#  'jadoons',
#  'imagebrad',
#  'sambodhi',
#  'blackhearts',
#  'ftrange',
#  'defanition',
#  'rushdie',
#  'refe',
#  'arz',
#  'evertighter',
#  'filebundesarchiv',
#  'asim',
#  'perkys',
#  '213942html',
#  'centredailycom',
#  'queenslands',
#  'generalonesojourner',
#  'exporessed',
#  'nationjpg',
#  'distin',
#  'sourceneil',
#  'hurricanefan25',
#  'stronhold',
#  '20312334138',
#  '261292',
#  'teremendous',
#  'fuch',
#  'juneja',
#  '20130214',
#  '1972006322',
#  'tomorrowsurf',
#  '9781622920020',
#  'cocoordinate',
#  'racistmntokherewmfdapits',
#  'tno',
#  'ocwhat',
#  'wwwrickallenmusiccom',
#  'marcellus',
#  'antiscandinavians',
#  'listbut',
#  'ubique',
#  '2121822853',
#  'tankreds',
#  'cdwow',
#  'unrefernced',
#  'bioeditors',
#  'subheaders',
#  '16185',
#  'druryrelated',
#  '2048rsa',
#  'untruthly',
#  'hydroplate',
#  'associationplease',
#  'indogreek20king20agathocles2020abhiraf',
#  'magicianprogrammer',
#  'desiro',
#  'raymi',
#  'checkedout',
#  'd0d4ff',
#  'horne',
#  'abiravan2c20in20eastern20iran2cf',
#  'honduran',
#  'talktheradioguy',
#  'lastretirement',
#  'artomat',
#  'talkrfa',
#  '251pm',
#  'tuss',
#  'farnborough',
#  '230',
#  'sotirios',
#  '12yroldnor',
#  'fuckoff',
#  'shatarupa',
#  'r160a',
#  'famale',
#  'forkbomb',
#  'investmentresearch',
#  'toyehtm',
#  'horsess',
#  'antifemale',
#  'talkebikeguy',
#  'frmlingsfientlig',
#  'altesse',
#  'mendes',
#  'wpnotpaper',
#  'aircars',
#  'beusar',
#  '1566311',
#  'websecurity',
#  'prestigiuos',
#  'kudrow',
#  'karem',
#  'liancourt',
#  'hazarika',
#  'frenchfried',
#  'relevanmt',
#  'southernfried',
#  'qrajarata',
#  'wpintegrity',
#  'cassiopeium',
#  'futperfect',
#  'newyorkrevolution02statrich',
#  'lart',
#  '7421693244',
#  'pfingsten',
#  'sbs6121x11',
#  'econtribsspeak',
#  'paginaarea',
#  'acceptancehttp',
#  'fotr',
#  'urbina',
#  '600mhz',
#  'anywayour',
#  'userprom3th3an',
#  'michigani',
#  'sharifs',
#  'psychiatristswhere',
#  'camraron',
#  'misunderstoodthe',
#  'erzebetthis',
#  'saintbnezet',
#  '292266526',
#  'joanie',
#  'collaborationcandidate',
#  'levadia',
#  'boyar',
#  'crankscorpion',
#  'croatizate',
#  'jepurovic',
#  'pepy',
#  'usercobblet',
#  '090511181356htm',
#  'tabbenji',
#  'kristof',
#  'imediatelly',
#  '00107',
#  '54th',
#  'shorther',
#  'grabar',
#  'paghman',
#  'pictire',
#  'bisexualand',
#  'pouluator',
#  'balochs',
#  'wwwpsprideorg',
#  'goodi',
#  'hedera',
#  'khazraj',
#  'libelldra',
#  'loverboyingarden',
#  'forcesplease',
#  'mashallah',
#  'wixifixer',
#  'talkzoo',
#  'gorillapitbull',
#  'fdb',
#  'critisise',
#  'maxtor',
#  'oldpeerreview',
#  'imagejoyceroopjpg',
#  'thingv',
#  'willyjeeves',
#  'imagevampire',
#  'wackpedia',
#  'vandelising',
#  'indeceny',
#  'theya',
#  'xelas',
#  'factchecks',
#  'mangan',
#  'googlefactblogspotcom',
#  'cyrillics',
#  'nairamdakh',
#  'skillswhere',
#  'sureunless',
#  'menat',
#  'continuuous',
#  'wpcustomsig',
#  'lipzipz',
#  'frecklefoot',
#  'imagespineljpg',
#  'notinherited',
#  'shinoda',
#  'voilating',
#  'exampledo',
#  'winchesters',
#  'kuebie',
#  'palafox',
#  '68191101192',
#  'authorjoseph',
#  '203206108116',
#  'selgin',
#  'gauteng',
#  '11619717883',
#  'lovelock',
#  '12079',
#  '8697573',
#  'julaha',
#  'westen',
#  'altffear',
#  'jatsand',
#  'ahhah',
#  'indexphptitleche',
#  'nationalismthe',
#  'ordoes',
#  'xrd',
#  'shuttegod',
#  'ideologys',
#  'mapsgooglees',
#  'wwwhmtreasurygovuk',
#  'goaround',
#  '63226104225',
#  'efroyal',
#  'imagefoxddsetjpg',
#  'wosner',
#  'titls',
#  'ryukyu',
#  'a352l5671334351c56713nlmakamaistreamnet',
#  '2028sbs6099c',
#  '2029sbs6171b',
#  'scevola',
#  'antiinflammatories',
#  'vindictiveyou',
#  '19721973',
#  'boscovichs',
#  'toskria',
#  'controversybe',
#  'feagans',
#  'corfu',
#  'ahmadiyyah',
#  '2118',
#  'greatgreatgrandfather',
#  'emeraude',
#  'tonethanks',
#  'isconsciously',
#  'iif',
#  'oligarchists',
#  'sourcesincluding',
#  'gomelsky',
#  'crosscategorization',
#  'padgett',
#  '861652045',
#  'chicagoans',
#  '1317i',
#  'draggings',
#  'siegman',
#  'shannara',
#  'hlenq',
#  '19881989',
#  'professionallooking',
#  'copins',
#  'dispted',
#  'caresthey',
#  'usersixgreenfish',
#  'wwwweekendait',
#  'cuking',
#  'wpadvert',
#  'coanchors',
#  'alsowhat',
#  'orsillo',
#  'alexaobriencom',
#  'wwwpsicofxpcom',
#  'commonsspecialupload',
#  'filestarbucks',
#  'tuggs',
#  'dinopup',
#  'longsince',
#  'mutsuhito',
#  'favorabe',
#  'theringis',
#  'royboycrashfan',
#  'hogganvik',
#  'articleonly',
#  'kurumada',
#  'authoritativethe',
#  'vulturing',
#  '1868',
#  'imagelarryclarkscameoinkenparkgif',
#  'planetif',
#  ...]

# %%
# Create a matrix of embeddings and pick the default values from the distribution of matrix weights
embeddings = np.stack(list(embedding_index.values())) # 3,000,000 by 300
embeddings_mean = embeddings.mean()
embeddings_std_dev = embeddings.std()
embedding_matrix = np.random.normal(embeddings_mean, embeddings_std_dev, (len(tokenizer.word_index), EMBEDDING_SIZE)) # 20,000 by 300

# %%
# For words from the source text (fed into the tokenizer), change the weights in the matrix to match their embedding values
for word, index in tokenizer.word_index.items():
    if word in embedding_index:
        embedding_matrix[index - 1] = embedding_index[word]

# %%
# Import model and layers used
from keras.models import Model
from keras.layers import  Embedding, Input, concatenate, SpatialDropout1D, Conv1D, GlobalMaxPooling1D, GlobalAveragePooling1D, Bidirectional, LSTM, Dense


# Use keras to define model
emb = Input(shape=(None,))
feat_eng = Input(shape=(2,))
x = Embedding(dict_size,embedding_matrix.shape[1], weights=[embedding_matrix], trainable=False)(emb)

x = SpatialDropout1D(0.2)(x)        
# Drop 1D Features of input matrix (i.e. row)

x = Bidirectional(LSTM(100, return_sequences = True, dropout = 0.2, recurrent_dropout = 0.2))(x)
# dropout = drop linear transformation of input
# recurrent_dropout = drop linear transformation of recurrent state
# return full hidden state output

x = GlobalMaxPooling1D()(x)
# To be location invariant

x = concatenate([feat_eng, x])
# Factor in numerical features and text

x = Dense(6, activation = "sigmoid")(x)
# Sigmoid encourages output components to be independent of each other (with softmax one high logit would push others lower)

model = Model([feat_eng, emb], x)
model.compile(loss = 'binary_crossentropy', optimizer= 'adam', metrics = ['accuracy'])
# Out:
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %%
# Fit model on our padded data
classifier = model.fit([train_x_eng,padded_train_x], train_y.values, batch_size = 1024, epochs = 5, validation_split = 0.1)
# Out:
# Epoch 1/5
# 141/141 [==============================] - 137s 970ms/step - loss: 0.1680 - accuracy: 0.9741 - val_loss: 0.1450 - val_accuracy: 0.9939
# Epoch 2/5
# 141/141 [==============================] - 133s 947ms/step - loss: 0.1379 - accuracy: 0.9937 - val_loss: 0.1231 - val_accuracy: 0.9940
# Epoch 3/5
# 141/141 [==============================] - 135s 957ms/step - loss: 0.1158 - accuracy: 0.9926 - val_loss: 0.0998 - val_accuracy: 0.9929
# Epoch 4/5
# 141/141 [==============================] - 136s 962ms/step - loss: 0.0953 - accuracy: 0.9930 - val_loss: 0.0865 - val_accuracy: 0.9933
# Epoch 5/5
# 141/141 [==============================] - 136s 963ms/step - loss: 0.0829 - accuracy: 0.9938 - val_loss: 0.0753 - val_accuracy: 0.9939

# %%
# Predict outcomes for our test data and save as a csv
prediction = model.predict( [test_x_eng, padded_test_x], batch_size = 1024)
sample_submission[["toxic", "severe_toxic", "obscene", "threat", "insult", "identity_hate"]] = prediction
sample_submission.to_csv('submission.csv', index = False)

# %% [markdown]
# Next Steps & Potential Changes:
#
# 1. Tuning Parameters
# 2. Experimenting with Architecture
# 3. Experimenting with different word embeddings (i.e. FastText)
# 4. Assessing model performance
